# %% [markdown]
# # Web-Project_API: Travel Advisory Data

# %% [markdown]
# ### I. Acquisition

# %%
#1 - I first import the necessary libraries:

import requests
import json
import pandas as pd

# %%
#2 - I then submit a request to my chosen API. I apply the '.json()' method afterwards.

ta_url = 'https://www.travel-advisory.info/api'
ta_request = requests.get(ta_url)
ta_json = ta_request.json()
ta_json
# Out:
# {'api_status': {'request': {'item': 'not specified'},
#   'reply': {'cache': 'renewed',
#    'code': 200,
#    'status': 'ok',
#    'note': 'The api works, we could fetch countries.',
#    'count': 238}},
#  'data': {'AD': {'iso_alpha2': 'AD',
#    'name': 'Andorra',
#    'continent': 'EU',
#    'advisory': {'score': 1.3,
#     'sources_active': 3,
#     'message': 'Andorra has a current risk level of 1.3 (out of 5). We advise: Travelling Andorra is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/andorra'}},
#   'AE': {'iso_alpha2': 'AE',
#    'name': 'United Arab Emirates',
#    'continent': 'AS',
#    'advisory': {'score': 2.3,
#     'sources_active': 6,
#     'message': 'United Arab Emirates has a current risk level of 2.3 (out of 5). We advise: Travelling United Arab Emirates is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/united-arab-emirates'}},
#   'AF': {'iso_alpha2': 'AF',
#    'name': 'Afghanistan',
#    'continent': 'AS',
#    'advisory': {'score': 5,
#     'sources_active': 10,
#     'message': 'Afghanistan has a current risk level of 5 (out of 5). We advise: It is not safe to travel Afghanistan.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/afghanistan'}},
#   'AG': {'iso_alpha2': 'AG',
#    'name': 'Antigua and Barbuda',
#    'continent': 'NA',
#    'advisory': {'score': 1,
#     'sources_active': 2,
#     'message': 'Antigua and Barbuda has a current risk level of 1 (out of 5). We advise: Travelling Antigua and Barbuda is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/antigua-and-barbuda'}},
#   'AI': {'iso_alpha2': 'AI',
#    'name': 'Anguilla',
#    'continent': 'NA',
#    'advisory': {'score': 1,
#     'sources_active': 2,
#     'message': 'Anguilla has a current risk level of 1 (out of 5). We advise: Travelling Anguilla is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/anguilla'}},
#   'AL': {'iso_alpha2': 'AL',
#    'name': 'Albania',
#    'continent': 'EU',
#    'advisory': {'score': 1.5,
#     'sources_active': 4,
#     'message': 'Albania has a current risk level of 1.5 (out of 5). We advise: Travelling Albania is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/albania'}},
#   'AM': {'iso_alpha2': 'AM',
#    'name': 'Armenia',
#    'continent': 'AS',
#    'advisory': {'score': 1.5,
#     'sources_active': 4,
#     'message': 'Armenia has a current risk level of 1.5 (out of 5). We advise: Travelling Armenia is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/armenia'}},
#   'AO': {'iso_alpha2': 'AO',
#    'name': 'Angola',
#    'continent': 'AF',
#    'advisory': {'score': 2,
#     'sources_active': 5,
#     'message': 'Angola has a current risk level of 2 (out of 5). We advise: Travelling Angola is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/angola'}},
#   'AR': {'iso_alpha2': 'AR',
#    'name': 'Argentina',
#    'continent': 'SA',
#    'advisory': {'score': 1.6,
#     'sources_active': 5,
#     'message': 'Argentina has a current risk level of 1.6 (out of 5). We advise: Travelling Argentina is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/argentina'}},
#   'AS': {'iso_alpha2': 'AS',
#    'name': 'American Samoa',
#    'continent': 'OC',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'American Samoa has a current risk level of 0 (out of 5). We advise: Travelling American Samoa is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/american-samoa'}},
#   'AT': {'iso_alpha2': 'AT',
#    'name': 'Austria',
#    'continent': 'EU',
#    'advisory': {'score': 1.3,
#     'sources_active': 3,
#     'message': 'Austria has a current risk level of 1.3 (out of 5). We advise: Travelling Austria is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/austria'}},
#   'AU': {'iso_alpha2': 'AU',
#    'name': 'Australia',
#    'continent': 'OC',
#    'advisory': {'score': 2,
#     'sources_active': 5,
#     'message': 'Australia has a current risk level of 2 (out of 5). We advise: Travelling Australia is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/australia'}},
#   'AW': {'iso_alpha2': 'AW',
#    'name': 'Aruba',
#    'continent': 'NA',
#    'advisory': {'score': 1,
#     'sources_active': 1,
#     'message': 'Aruba has a current risk level of 1 (out of 5). We advise: Travelling Aruba is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/aruba'}},
#   'AZ': {'iso_alpha2': 'AZ',
#    'name': 'Azerbaijan',
#    'continent': 'AS',
#    'advisory': {'score': 2.6,
#     'sources_active': 5,
#     'message': 'Azerbaijan has a current risk level of 2.6 (out of 5). We advise: Use some caution when travelling Azerbaijan.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/azerbaijan'}},
#   'BA': {'iso_alpha2': 'BA',
#    'name': 'Bosnia and Herzegovina',
#    'continent': 'EU',
#    'advisory': {'score': 2,
#     'sources_active': 4,
#     'message': 'Bosnia and Herzegovina has a current risk level of 2 (out of 5). We advise: Travelling Bosnia and Herzegovina is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/bosnia-and-herzegovina'}},
#   'BB': {'iso_alpha2': 'BB',
#    'name': 'Barbados',
#    'continent': 'NA',
#    'advisory': {'score': 2,
#     'sources_active': 3,
#     'message': 'Barbados has a current risk level of 2 (out of 5). We advise: Travelling Barbados is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/barbados'}},
#   'BD': {'iso_alpha2': 'BD',
#    'name': 'Bangladesh',
#    'continent': 'AS',
#    'advisory': {'score': 2.7,
#     'sources_active': 7,
#     'message': 'Bangladesh has a current risk level of 2.7 (out of 5). We advise: Use some caution when travelling Bangladesh.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/bangladesh'}},
#   'BE': {'iso_alpha2': 'BE',
#    'name': 'Belgium',
#    'continent': 'EU',
#    'advisory': {'score': 2.3,
#     'sources_active': 6,
#     'message': 'Belgium has a current risk level of 2.3 (out of 5). We advise: Travelling Belgium is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/belgium'}},
#   'BF': {'iso_alpha2': 'BF',
#    'name': 'Burkina Faso',
#    'continent': 'AF',
#    'advisory': {'score': 3.8,
#     'sources_active': 8,
#     'message': 'Burkina Faso has a current risk level of 3.8 (out of 5). We advise: Please reconsider your need to travel to Burkina Faso.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/burkina-faso'}},
#   'BG': {'iso_alpha2': 'BG',
#    'name': 'Bulgaria',
#    'continent': 'EU',
#    'advisory': {'score': 1.5,
#     'sources_active': 4,
#     'message': 'Bulgaria has a current risk level of 1.5 (out of 5). We advise: Travelling Bulgaria is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/bulgaria'}},
#   'BH': {'iso_alpha2': 'BH',
#    'name': 'Bahrain',
#    'continent': 'AS',
#    'advisory': {'score': 2.2,
#     'sources_active': 5,
#     'message': 'Bahrain has a current risk level of 2.2 (out of 5). We advise: Travelling Bahrain is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/bahrain'}},
#   'BI': {'iso_alpha2': 'BI',
#    'name': 'Burundi',
#    'continent': 'AF',
#    'advisory': {'score': 4.8,
#     'sources_active': 6,
#     'message': 'Burundi has a current risk level of 4.8 (out of 5). We advise: It is not safe to travel Burundi.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/burundi'}},
#   'BJ': {'iso_alpha2': 'BJ',
#    'name': 'Benin',
#    'continent': 'AF',
#    'advisory': {'score': 2,
#     'sources_active': 3,
#     'message': 'Benin has a current risk level of 2 (out of 5). We advise: Travelling Benin is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/benin'}},
#   'BL': {'iso_alpha2': 'BL',
#    'name': 'Saint Barthélemy',
#    'continent': 'NA',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'Saint Barthélemy has a current risk level of 0 (out of 5). We advise: Travelling Saint Barthélemy is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/saint-barthelemy'}},
#   'BM': {'iso_alpha2': 'BM',
#    'name': 'Bermuda',
#    'continent': 'NA',
#    'advisory': {'score': 1,
#     'sources_active': 2,
#     'message': 'Bermuda has a current risk level of 1 (out of 5). We advise: Travelling Bermuda is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/bermuda'}},
#   'BN': {'iso_alpha2': 'BN',
#    'name': 'Brunei',
#    'continent': 'AS',
#    'advisory': {'score': 1.3,
#     'sources_active': 3,
#     'message': 'Brunei has a current risk level of 1.3 (out of 5). We advise: Travelling Brunei is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/brunei'}},
#   'BO': {'iso_alpha2': 'BO',
#    'name': 'Bolivia',
#    'continent': 'SA',
#    'advisory': {'score': 2.7,
#     'sources_active': 6,
#     'message': 'Bolivia has a current risk level of 2.7 (out of 5). We advise: Use some caution when travelling Bolivia.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/bolivia'}},
#   'BR': {'iso_alpha2': 'BR',
#    'name': 'Brazil',
#    'continent': 'SA',
#    'advisory': {'score': 2.3,
#     'sources_active': 7,
#     'message': 'Brazil has a current risk level of 2.3 (out of 5). We advise: Travelling Brazil is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/brazil'}},
#   'BS': {'iso_alpha2': 'BS',
#    'name': 'Bahamas',
#    'continent': 'NA',
#    'advisory': {'score': 2.3,
#     'sources_active': 4,
#     'message': 'Bahamas has a current risk level of 2.3 (out of 5). We advise: Travelling Bahamas is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/bahamas'}},
#   'BT': {'iso_alpha2': 'BT',
#    'name': 'Bhutan',
#    'continent': 'AS',
#    'advisory': {'score': 1.3,
#     'sources_active': 3,
#     'message': 'Bhutan has a current risk level of 1.3 (out of 5). We advise: Travelling Bhutan is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/bhutan'}},
#   'BW': {'iso_alpha2': 'BW',
#    'name': 'Botswana',
#    'continent': 'AF',
#    'advisory': {'score': 1.3,
#     'sources_active': 3,
#     'message': 'Botswana has a current risk level of 1.3 (out of 5). We advise: Travelling Botswana is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/botswana'}},
#   'BY': {'iso_alpha2': 'BY',
#    'name': 'Belarus',
#    'continent': 'EU',
#    'advisory': {'score': 1.3,
#     'sources_active': 3,
#     'message': 'Belarus has a current risk level of 1.3 (out of 5). We advise: Travelling Belarus is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/belarus'}},
#   'BZ': {'iso_alpha2': 'BZ',
#    'name': 'Belize',
#    'continent': 'NA',
#    'advisory': {'score': 2.4,
#     'sources_active': 5,
#     'message': 'Belize has a current risk level of 2.4 (out of 5). We advise: Travelling Belize is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/belize'}},
#   'CA': {'iso_alpha2': 'CA',
#    'name': 'Canada',
#    'continent': 'NA',
#    'advisory': {'score': 1.5,
#     'sources_active': 4,
#     'message': 'Canada has a current risk level of 1.5 (out of 5). We advise: Travelling Canada is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/canada'}},
#   'CC': {'iso_alpha2': 'CC',
#    'name': 'Cocos Islands',
#    'continent': 'SA',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'Cocos Islands has a current risk level of 0 (out of 5). We advise: Travelling Cocos Islands is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/cocos-islands'}},
#   'CD': {'iso_alpha2': 'CD',
#    'name': 'Democratic Republic of the Congo',
#    'continent': 'AF',
#    'advisory': {'score': 3.8,
#     'sources_active': 8,
#     'message': 'Democratic Republic of the Congo has a current risk level of 3.8 (out of 5). We advise: Please reconsider your need to travel to Democratic Republic of the Congo.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/democratic-republic-of-the-congo'}},
#   'CF': {'iso_alpha2': 'CF',
#    'name': 'Central African Republic',
#    'continent': 'AF',
#    'advisory': {'score': 5,
#     'sources_active': 8,
#     'message': 'Central African Republic has a current risk level of 5 (out of 5). We advise: It is not safe to travel Central African Republic.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/central-african-republic'}},
#   'CG': {'iso_alpha2': 'CG',
#    'name': 'Republic of the Congo',
#    'continent': 'AF',
#    'advisory': {'score': 2.3,
#     'sources_active': 4,
#     'message': 'Republic of the Congo has a current risk level of 2.3 (out of 5). We advise: Travelling Republic of the Congo is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/republic-of-the-congo'}},
#   'CH': {'iso_alpha2': 'CH',
#    'name': 'Switzerland',
#    'continent': 'EU',
#    'advisory': {'score': 1.5,
#     'sources_active': 2,
#     'message': 'Switzerland has a current risk level of 1.5 (out of 5). We advise: Travelling Switzerland is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/switzerland'}},
#   'CI': {'iso_alpha2': 'CI',
#    'name': 'Ivory Coast',
#    'continent': 'AF',
#    'advisory': {'score': 2.7,
#     'sources_active': 6,
#     'message': 'Ivory Coast has a current risk level of 2.7 (out of 5). We advise: Use some caution when travelling Ivory Coast.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/ivory-coast'}},
#   'CK': {'iso_alpha2': 'CK',
#    'name': 'Cook Islands',
#    'continent': 'OC',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'Cook Islands has a current risk level of 0 (out of 5). We advise: Travelling Cook Islands is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/cook-islands'}},
#   'CL': {'iso_alpha2': 'CL',
#    'name': 'Chile',
#    'continent': 'SA',
#    'advisory': {'score': 2.5,
#     'sources_active': 6,
#     'message': 'Chile has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling Chile.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/chile'}},
#   'CM': {'iso_alpha2': 'CM',
#    'name': 'Cameroon',
#    'continent': 'AF',
#    'advisory': {'score': 2.5,
#     'sources_active': 6,
#     'message': 'Cameroon has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling Cameroon.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/cameroon'}},
#   'CN': {'iso_alpha2': 'CN',
#    'name': 'China',
#    'continent': 'AS',
#    'advisory': {'score': 3.9,
#     'sources_active': 9,
#     'message': 'China has a current risk level of 3.9 (out of 5). We advise: Please reconsider your need to travel to China.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/china'}},
#   'CO': {'iso_alpha2': 'CO',
#    'name': 'Colombia',
#    'continent': 'SA',
#    'advisory': {'score': 2.5,
#     'sources_active': 6,
#     'message': 'Colombia has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling Colombia.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/colombia'}},
#   'CR': {'iso_alpha2': 'CR',
#    'name': 'Costa Rica',
#    'continent': 'NA',
#    'advisory': {'score': 2.4,
#     'sources_active': 5,
#     'message': 'Costa Rica has a current risk level of 2.4 (out of 5). We advise: Travelling Costa Rica is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/costa-rica'}},
#   'CU': {'iso_alpha2': 'CU',
#    'name': 'Cuba',
#    'continent': 'NA',
#    'advisory': {'score': 2.3,
#     'sources_active': 3,
#     'message': 'Cuba has a current risk level of 2.3 (out of 5). We advise: Travelling Cuba is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/cuba'}},
#   'CV': {'iso_alpha2': 'CV',
#    'name': 'Cape Verde',
#    'continent': 'AF',
#    'advisory': {'score': 2.3,
#     'sources_active': 4,
#     'message': 'Cape Verde has a current risk level of 2.3 (out of 5). We advise: Travelling Cape Verde is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/cape-verde'}},
#   'CX': {'iso_alpha2': 'CX',
#    'name': 'Christmas Island',
#    'continent': 'OC',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'Christmas Island has a current risk level of 0 (out of 5). We advise: Travelling Christmas Island is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/christmas-island'}},
#   'CY': {'iso_alpha2': 'CY',
#    'name': 'Cyprus',
#    'continent': 'EU',
#    'advisory': {'score': 1.3,
#     'sources_active': 3,
#     'message': 'Cyprus has a current risk level of 1.3 (out of 5). We advise: Travelling Cyprus is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/cyprus'}},
#   'CZ': {'iso_alpha2': 'CZ',
#    'name': 'Czech Republic',
#    'continent': 'EU',
#    'advisory': {'score': 1.5,
#     'sources_active': 4,
#     'message': 'Czech Republic has a current risk level of 1.5 (out of 5). We advise: Travelling Czech Republic is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/czech-republic'}},
#   'DE': {'iso_alpha2': 'DE',
#    'name': 'Germany',
#    'continent': 'EU',
#    'advisory': {'score': 2,
#     'sources_active': 5,
#     'message': 'Germany has a current risk level of 2 (out of 5). We advise: Travelling Germany is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/germany'}},
#   'DJ': {'iso_alpha2': 'DJ',
#    'name': 'Djibouti',
#    'continent': 'AF',
#    'advisory': {'score': 2.2,
#     'sources_active': 5,
#     'message': 'Djibouti has a current risk level of 2.2 (out of 5). We advise: Travelling Djibouti is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/djibouti'}},
#   'DK': {'iso_alpha2': 'DK',
#    'name': 'Denmark',
#    'continent': 'EU',
#    'advisory': {'score': 1.8,
#     'sources_active': 4,
#     'message': 'Denmark has a current risk level of 1.8 (out of 5). We advise: Travelling Denmark is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/denmark'}},
#   'DM': {'iso_alpha2': 'DM',
#    'name': 'Dominica',
#    'continent': 'NA',
#    'advisory': {'score': 2.5,
#     'sources_active': 2,
#     'message': 'Dominica has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling Dominica.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/dominica'}},
#   'DO': {'iso_alpha2': 'DO',
#    'name': 'Dominican Republic',
#    'continent': 'NA',
#    'advisory': {'score': 2.5,
#     'sources_active': 4,
#     'message': 'Dominican Republic has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling Dominican Republic.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/dominican-republic'}},
#   'DZ': {'iso_alpha2': 'DZ',
#    'name': 'Algeria',
#    'continent': 'AF',
#    'advisory': {'score': 2.8,
#     'sources_active': 10,
#     'message': 'Algeria has a current risk level of 2.8 (out of 5). We advise: Use some caution when travelling Algeria.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/algeria'}},
#   'EC': {'iso_alpha2': 'EC',
#    'name': 'Ecuador',
#    'continent': 'SA',
#    'advisory': {'score': 2.5,
#     'sources_active': 6,
#     'message': 'Ecuador has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling Ecuador.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/ecuador'}},
#   'EE': {'iso_alpha2': 'EE',
#    'name': 'Estonia',
#    'continent': 'EU',
#    'advisory': {'score': 1.5,
#     'sources_active': 4,
#     'message': 'Estonia has a current risk level of 1.5 (out of 5). We advise: Travelling Estonia is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/estonia'}},
#   'EG': {'iso_alpha2': 'EG',
#    'name': 'Egypt',
#    'continent': 'AF',
#    'advisory': {'score': 2.8,
#     'sources_active': 10,
#     'message': 'Egypt has a current risk level of 2.8 (out of 5). We advise: Use some caution when travelling Egypt.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/egypt'}},
#   'EH': {'iso_alpha2': 'EH',
#    'name': 'Western Sahara',
#    'continent': 'AF',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'Western Sahara has a current risk level of 0 (out of 5). We advise: Travelling Western Sahara is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/western-sahara'}},
#   'ER': {'iso_alpha2': 'ER',
#    'name': 'Eritrea',
#    'continent': 'AF',
#    'advisory': {'score': 3.3,
#     'sources_active': 7,
#     'message': 'Eritrea has a current risk level of 3.3 (out of 5). We advise: Use some caution when travelling Eritrea.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/eritrea'}},
#   'ES': {'iso_alpha2': 'ES',
#    'name': 'Spain',
#    'continent': 'EU',
#    'advisory': {'score': 2,
#     'sources_active': 5,
#     'message': 'Spain has a current risk level of 2 (out of 5). We advise: Travelling Spain is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/spain'}},
#   'ET': {'iso_alpha2': 'ET',
#    'name': 'Ethiopia',
#    'continent': 'AF',
#    'advisory': {'score': 2.6,
#     'sources_active': 7,
#     'message': 'Ethiopia has a current risk level of 2.6 (out of 5). We advise: Use some caution when travelling Ethiopia.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/ethiopia'}},
#   'FI': {'iso_alpha2': 'FI',
#    'name': 'Finland',
#    'continent': 'EU',
#    'advisory': {'score': 1.3,
#     'sources_active': 3,
#     'message': 'Finland has a current risk level of 1.3 (out of 5). We advise: Travelling Finland is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/finland'}},
#   'FJ': {'iso_alpha2': 'FJ',
#    'name': 'Fiji',
#    'continent': 'OC',
#    'advisory': {'score': 1.3,
#     'sources_active': 3,
#     'message': 'Fiji has a current risk level of 1.3 (out of 5). We advise: Travelling Fiji is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/fiji'}},
#   'FK': {'iso_alpha2': 'FK',
#    'name': 'Falkland Islands',
#    'continent': 'SA',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'Falkland Islands has a current risk level of 0 (out of 5). We advise: Travelling Falkland Islands is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/falkland-islands'}},
#   'FM': {'iso_alpha2': 'FM',
#    'name': 'Micronesia',
#    'continent': 'OC',
#    'advisory': {'score': 1,
#     'sources_active': 1,
#     'message': 'Micronesia has a current risk level of 1 (out of 5). We advise: Travelling Micronesia is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/micronesia'}},
#   'FO': {'iso_alpha2': 'FO',
#    'name': 'Faroe Islands',
#    'continent': 'EU',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'Faroe Islands has a current risk level of 0 (out of 5). We advise: Travelling Faroe Islands is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/faroe-islands'}},
#   'FR': {'iso_alpha2': 'FR',
#    'name': 'France',
#    'continent': 'EU',
#    'advisory': {'score': 2.5,
#     'sources_active': 6,
#     'message': 'France has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling France.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/france'}},
#   'GA': {'iso_alpha2': 'GA',
#    'name': 'Gabon',
#    'continent': 'AF',
#    'advisory': {'score': 2.3,
#     'sources_active': 3,
#     'message': 'Gabon has a current risk level of 2.3 (out of 5). We advise: Travelling Gabon is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/gabon'}},
#   'GB': {'iso_alpha2': 'GB',
#    'name': 'United Kingdom',
#    'continent': 'EU',
#    'advisory': {'score': 2,
#     'sources_active': 6,
#     'message': 'United Kingdom has a current risk level of 2 (out of 5). We advise: Travelling United Kingdom is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/united-kingdom'}},
#   'GD': {'iso_alpha2': 'GD',
#    'name': 'Grenada',
#    'continent': 'NA',
#    'advisory': {'score': 1,
#     'sources_active': 2,
#     'message': 'Grenada has a current risk level of 1 (out of 5). We advise: Travelling Grenada is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/grenada'}},
#   'GE': {'iso_alpha2': 'GE',
#    'name': 'Georgia',
#    'continent': 'AS',
#    'advisory': {'score': 1.3,
#     'sources_active': 3,
#     'message': 'Georgia has a current risk level of 1.3 (out of 5). We advise: Travelling Georgia is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/georgia'}},
#   'GF': {'iso_alpha2': 'GF',
#    'name': 'French Guiana',
#    'continent': 'SA',
#    'advisory': {'score': 3,
#     'sources_active': 1,
#     'message': 'French Guiana has a current risk level of 3 (out of 5). We advise: Use some caution when travelling French Guiana.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/french-guiana'}},
#   'GG': {'iso_alpha2': 'GG',
#    'name': 'Guernsey',
#    'continent': 'EU',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'Guernsey has a current risk level of 0 (out of 5). We advise: Travelling Guernsey is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/guernsey'}},
#   'GH': {'iso_alpha2': 'GH',
#    'name': 'Ghana',
#    'continent': 'AF',
#    'advisory': {'score': 2.5,
#     'sources_active': 4,
#     'message': 'Ghana has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling Ghana.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/ghana'}},
#   'GI': {'iso_alpha2': 'GI',
#    'name': 'Gibraltar',
#    'continent': 'EU',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'Gibraltar has a current risk level of 0 (out of 5). We advise: Travelling Gibraltar is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/gibraltar'}},
#   'GL': {'iso_alpha2': 'GL',
#    'name': 'Greenland',
#    'continent': 'NA',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'Greenland has a current risk level of 0 (out of 5). We advise: Travelling Greenland is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/greenland'}},
#   'GM': {'iso_alpha2': 'GM',
#    'name': 'Gambia',
#    'continent': 'AF',
#    'advisory': {'score': 2.4,
#     'sources_active': 5,
#     'message': 'Gambia has a current risk level of 2.4 (out of 5). We advise: Travelling Gambia is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/gambia'}},
#   'GN': {'iso_alpha2': 'GN',
#    'name': 'Guinea',
#    'continent': 'AF',
#    'advisory': {'score': 2.5,
#     'sources_active': 4,
#     'message': 'Guinea has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling Guinea.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/guinea'}},
#   'GP': {'iso_alpha2': 'GP',
#    'name': 'Guadeloupe',
#    'continent': 'NA',
#    'advisory': {'score': 1,
#     'sources_active': 1,
#     'message': 'Guadeloupe has a current risk level of 1 (out of 5). We advise: Travelling Guadeloupe is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/guadeloupe'}},
#   'GQ': {'iso_alpha2': 'GQ',
#    'name': 'Equatorial Guinea',
#    'continent': 'AF',
#    'advisory': {'score': 2.3,
#     'sources_active': 3,
#     'message': 'Equatorial Guinea has a current risk level of 2.3 (out of 5). We advise: Travelling Equatorial Guinea is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/equatorial-guinea'}},
#   'GR': {'iso_alpha2': 'GR',
#    'name': 'Greece',
#    'continent': 'EU',
#    'advisory': {'score': 1.6,
#     'sources_active': 5,
#     'message': 'Greece has a current risk level of 1.6 (out of 5). We advise: Travelling Greece is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/greece'}},
#   'GS': {'iso_alpha2': 'GS',
#    'name': 'South Georgia and the South Sandwich Islands',
#    'continent': 'AN',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'South Georgia and the South Sandwich Islands has a current risk level of 0 (out of 5). We advise: Travelling South Georgia and the South Sandwich Islands is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/south-georgia-and-the-south-sandwich-islands'}},
#   'GT': {'iso_alpha2': 'GT',
#    'name': 'Guatemala',
#    'continent': 'NA',
#    'advisory': {'score': 2.6,
#     'sources_active': 5,
#     'message': 'Guatemala has a current risk level of 2.6 (out of 5). We advise: Use some caution when travelling Guatemala.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/guatemala'}},
#   'GU': {'iso_alpha2': 'GU',
#    'name': 'Guam',
#    'continent': 'OC',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'Guam has a current risk level of 0 (out of 5). We advise: Travelling Guam is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/guam'}},
#   'GW': {'iso_alpha2': 'GW',
#    'name': 'Guinea-Bissau',
#    'continent': 'AF',
#    'advisory': {'score': 2.7,
#     'sources_active': 3,
#     'message': 'Guinea-Bissau has a current risk level of 2.7 (out of 5). We advise: Use some caution when travelling Guinea-Bissau.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/guinea-bissau'}},
#   'GY': {'iso_alpha2': 'GY',
#    'name': 'Guyana',
#    'continent': 'SA',
#    'advisory': {'score': 2.5,
#     'sources_active': 4,
#     'message': 'Guyana has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling Guyana.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/guyana'}},
#   'HK': {'iso_alpha2': 'HK',
#    'name': 'Hong Kong',
#    'continent': 'AS',
#    'advisory': {'score': 2.6,
#     'sources_active': 5,
#     'message': 'Hong Kong has a current risk level of 2.6 (out of 5). We advise: Use some caution when travelling Hong Kong.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/hong-kong'}},
#   'HN': {'iso_alpha2': 'HN',
#    'name': 'Honduras',
#    'continent': 'NA',
#    'advisory': {'score': 2.8,
#     'sources_active': 5,
#     'message': 'Honduras has a current risk level of 2.8 (out of 5). We advise: Use some caution when travelling Honduras.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/honduras'}},
#   'HR': {'iso_alpha2': 'HR',
#    'name': 'Croatia',
#    'continent': 'EU',
#    'advisory': {'score': 1.5,
#     'sources_active': 4,
#     'message': 'Croatia has a current risk level of 1.5 (out of 5). We advise: Travelling Croatia is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/croatia'}},
#   'HT': {'iso_alpha2': 'HT',
#    'name': 'Haiti',
#    'continent': 'NA',
#    'advisory': {'score': 4.2,
#     'sources_active': 6,
#     'message': 'Haiti has a current risk level of 4.2 (out of 5). We advise: Please reconsider your need to travel to Haiti.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/haiti'}},
#   'HU': {'iso_alpha2': 'HU',
#    'name': 'Hungary',
#    'continent': 'EU',
#    'advisory': {'score': 1.5,
#     'sources_active': 4,
#     'message': 'Hungary has a current risk level of 1.5 (out of 5). We advise: Travelling Hungary is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/hungary'}},
#   'ID': {'iso_alpha2': 'ID',
#    'name': 'Indonesia',
#    'continent': 'AS',
#    'advisory': {'score': 2.5,
#     'sources_active': 6,
#     'message': 'Indonesia has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling Indonesia.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/indonesia'}},
#   'IE': {'iso_alpha2': 'IE',
#    'name': 'Ireland',
#    'continent': 'EU',
#    'advisory': {'score': 1.5,
#     'sources_active': 2,
#     'message': 'Ireland has a current risk level of 1.5 (out of 5). We advise: Travelling Ireland is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/ireland'}},
#   'IL': {'iso_alpha2': 'IL',
#    'name': 'Israel',
#    'continent': 'AS',
#    'advisory': {'score': 2.7,
#     'sources_active': 6,
#     'message': 'Israel has a current risk level of 2.7 (out of 5). We advise: Use some caution when travelling Israel.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/israel'}},
#   'IM': {'iso_alpha2': 'IM',
#    'name': 'Isle of Man',
#    'continent': 'EU',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'Isle of Man has a current risk level of 0 (out of 5). We advise: Travelling Isle of Man is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/isle-of-man'}},
#   'IN': {'iso_alpha2': 'IN',
#    'name': 'India',
#    'continent': 'AS',
#    'advisory': {'score': 2.6,
#     'sources_active': 7,
#     'message': 'India has a current risk level of 2.6 (out of 5). We advise: Use some caution when travelling India.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/india'}},
#   'IQ': {'iso_alpha2': 'IQ',
#    'name': 'Iraq',
#    'continent': 'AS',
#    'advisory': {'score': 4.7,
#     'sources_active': 9,
#     'message': 'Iraq has a current risk level of 4.7 (out of 5). We advise: It is not safe to travel Iraq.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/iraq'}},
#   'IR': {'iso_alpha2': 'IR',
#    'name': 'Iran',
#    'continent': 'AS',
#    'advisory': {'score': 4.6,
#     'sources_active': 7,
#     'message': 'Iran has a current risk level of 4.6 (out of 5). We advise: It is not safe to travel Iran.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/iran'}},
#   'IS': {'iso_alpha2': 'IS',
#    'name': 'Iceland',
#    'continent': 'EU',
#    'advisory': {'score': 1.5,
#     'sources_active': 4,
#     'message': 'Iceland has a current risk level of 1.5 (out of 5). We advise: Travelling Iceland is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/iceland'}},
#   'IT': {'iso_alpha2': 'IT',
#    'name': 'Italy',
#    'continent': 'EU',
#    'advisory': {'score': 3,
#     'sources_active': 7,
#     'message': 'Italy has a current risk level of 3 (out of 5). We advise: Use some caution when travelling Italy.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/italy'}},
#   'JE': {'iso_alpha2': 'JE',
#    'name': 'Jersey',
#    'continent': 'EU',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'Jersey has a current risk level of 0 (out of 5). We advise: Travelling Jersey is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/jersey'}},
#   'JM': {'iso_alpha2': 'JM',
#    'name': 'Jamaica',
#    'continent': 'NA',
#    'advisory': {'score': 2.6,
#     'sources_active': 5,
#     'message': 'Jamaica has a current risk level of 2.6 (out of 5). We advise: Use some caution when travelling Jamaica.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/jamaica'}},
#   'JO': {'iso_alpha2': 'JO',
#    'name': 'Jordan',
#    'continent': 'AS',
#    'advisory': {'score': 2.5,
#     'sources_active': 6,
#     'message': 'Jordan has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling Jordan.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/jordan'}},
#   'JP': {'iso_alpha2': 'JP',
#    'name': 'Japan',
#    'continent': 'AS',
#    'advisory': {'score': 2.1,
#     'sources_active': 7,
#     'message': 'Japan has a current risk level of 2.1 (out of 5). We advise: Travelling Japan is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/japan'}},
#   'KE': {'iso_alpha2': 'KE',
#    'name': 'Kenya',
#    'continent': 'AF',
#    'advisory': {'score': 2.6,
#     'sources_active': 8,
#     'message': 'Kenya has a current risk level of 2.6 (out of 5). We advise: Use some caution when travelling Kenya.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/kenya'}},
#   'KG': {'iso_alpha2': 'KG',
#    'name': 'Kyrgyzstan',
#    'continent': 'AS',
#    'advisory': {'score': 2.2,
#     'sources_active': 5,
#     'message': 'Kyrgyzstan has a current risk level of 2.2 (out of 5). We advise: Travelling Kyrgyzstan is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/kyrgyzstan'}},
#   'KH': {'iso_alpha2': 'KH',
#    'name': 'Cambodia',
#    'continent': 'AS',
#    'advisory': {'score': 2,
#     'sources_active': 5,
#     'message': 'Cambodia has a current risk level of 2 (out of 5). We advise: Travelling Cambodia is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/cambodia'}},
#   'KI': {'iso_alpha2': 'KI',
#    'name': 'Kiribati',
#    'continent': 'OC',
#    'advisory': {'score': 1,
#     'sources_active': 1,
#     'message': 'Kiribati has a current risk level of 1 (out of 5). We advise: Travelling Kiribati is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/kiribati'}},
#   'KM': {'iso_alpha2': 'KM',
#    'name': 'Comoros',
#    'continent': 'AF',
#    'advisory': {'score': 2.3,
#     'sources_active': 3,
#     'message': 'Comoros has a current risk level of 2.3 (out of 5). We advise: Travelling Comoros is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/comoros'}},
#   'KN': {'iso_alpha2': 'KN',
#    'name': 'Saint Kitts and Nevis',
#    'continent': 'NA',
#    'advisory': {'score': 1,
#     'sources_active': 2,
#     'message': 'Saint Kitts and Nevis has a current risk level of 1 (out of 5). We advise: Travelling Saint Kitts and Nevis is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/saint-kitts-and-nevis'}},
#   'KP': {'iso_alpha2': 'KP',
#    'name': 'North Korea',
#    'continent': 'AS',
#    'advisory': {'score': 4.3,
#     'sources_active': 6,
#     'message': 'North Korea has a current risk level of 4.3 (out of 5). We advise: Please reconsider your need to travel to North Korea.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/north-korea'}},
#   'KR': {'iso_alpha2': 'KR',
#    'name': 'South Korea',
#    'continent': 'AS',
#    'advisory': {'score': 2.7,
#     'sources_active': 6,
#     'message': 'South Korea has a current risk level of 2.7 (out of 5). We advise: Use some caution when travelling South Korea.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/south-korea'}},
#   'KW': {'iso_alpha2': 'KW',
#    'name': 'Kuwait',
#    'continent': 'AS',
#    'advisory': {'score': 2,
#     'sources_active': 5,
#     'message': 'Kuwait has a current risk level of 2 (out of 5). We advise: Travelling Kuwait is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/kuwait'}},
#   'KY': {'iso_alpha2': 'KY',
#    'name': 'Cayman Islands',
#    'continent': 'NA',
#    'advisory': {'score': 1,
#     'sources_active': 2,
#     'message': 'Cayman Islands has a current risk level of 1 (out of 5). We advise: Travelling Cayman Islands is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/cayman-islands'}},
#   'KZ': {'iso_alpha2': 'KZ',
#    'name': 'Kazakhstan',
#    'continent': 'AS',
#    'advisory': {'score': 2.2,
#     'sources_active': 5,
#     'message': 'Kazakhstan has a current risk level of 2.2 (out of 5). We advise: Travelling Kazakhstan is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/kazakhstan'}},
#   'LA': {'iso_alpha2': 'LA',
#    'name': 'Laos',
#    'continent': 'AS',
#    'advisory': {'score': 1.5,
#     'sources_active': 4,
#     'message': 'Laos has a current risk level of 1.5 (out of 5). We advise: Travelling Laos is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/laos'}},
#   'LB': {'iso_alpha2': 'LB',
#    'name': 'Lebanon',
#    'continent': 'AS',
#    'advisory': {'score': 2.9,
#     'sources_active': 9,
#     'message': 'Lebanon has a current risk level of 2.9 (out of 5). We advise: Use some caution when travelling Lebanon.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/lebanon'}},
#   'LC': {'iso_alpha2': 'LC',
#    'name': 'Saint Lucia',
#    'continent': 'NA',
#    'advisory': {'score': 1,
#     'sources_active': 2,
#     'message': 'Saint Lucia has a current risk level of 1 (out of 5). We advise: Travelling Saint Lucia is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/saint-lucia'}},
#   'LI': {'iso_alpha2': 'LI',
#    'name': 'Liechtenstein',
#    'continent': 'EU',
#    'advisory': {'score': 1.3,
#     'sources_active': 3,
#     'message': 'Liechtenstein has a current risk level of 1.3 (out of 5). We advise: Travelling Liechtenstein is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/liechtenstein'}},
#   'LK': {'iso_alpha2': 'LK',
#    'name': 'Sri Lanka',
#    'continent': 'AS',
#    'advisory': {'score': 2.7,
#     'sources_active': 7,
#     'message': 'Sri Lanka has a current risk level of 2.7 (out of 5). We advise: Use some caution when travelling Sri Lanka.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/sri-lanka'}},
#   'LR': {'iso_alpha2': 'LR',
#    'name': 'Liberia',
#    'continent': 'AF',
#    'advisory': {'score': 2.3,
#     'sources_active': 4,
#     'message': 'Liberia has a current risk level of 2.3 (out of 5). We advise: Travelling Liberia is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/liberia'}},
#   'LS': {'iso_alpha2': 'LS',
#    'name': 'Lesotho',
#    'continent': 'AF',
#    'advisory': {'score': 2.3,
#     'sources_active': 4,
#     'message': 'Lesotho has a current risk level of 2.3 (out of 5). We advise: Travelling Lesotho is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/lesotho'}},
#   'LT': {'iso_alpha2': 'LT',
#    'name': 'Lithuania',
#    'continent': 'EU',
#    'advisory': {'score': 1.5,
#     'sources_active': 4,
#     'message': 'Lithuania has a current risk level of 1.5 (out of 5). We advise: Travelling Lithuania is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/lithuania'}},
#   'LU': {'iso_alpha2': 'LU',
#    'name': 'Luxembourg',
#    'continent': 'EU',
#    'advisory': {'score': 1.3,
#     'sources_active': 3,
#     'message': 'Luxembourg has a current risk level of 1.3 (out of 5). We advise: Travelling Luxembourg is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/luxembourg'}},
#   'LV': {'iso_alpha2': 'LV',
#    'name': 'Latvia',
#    'continent': 'EU',
#    'advisory': {'score': 1.5,
#     'sources_active': 4,
#     'message': 'Latvia has a current risk level of 1.5 (out of 5). We advise: Travelling Latvia is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/latvia'}},
#   'LY': {'iso_alpha2': 'LY',
#    'name': 'Libya',
#    'continent': 'AF',
#    'advisory': {'score': 5,
#     'sources_active': 9,
#     'message': 'Libya has a current risk level of 5 (out of 5). We advise: It is not safe to travel Libya.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/libya'}},
#   'MA': {'iso_alpha2': 'MA',
#    'name': 'Morocco',
#    'continent': 'AF',
#    'advisory': {'score': 2.4,
#     'sources_active': 7,
#     'message': 'Morocco has a current risk level of 2.4 (out of 5). We advise: Travelling Morocco is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/morocco'}},
#   'MC': {'iso_alpha2': 'MC',
#    'name': 'Monaco',
#    'continent': 'EU',
#    'advisory': {'score': 1.5,
#     'sources_active': 2,
#     'message': 'Monaco has a current risk level of 1.5 (out of 5). We advise: Travelling Monaco is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/monaco'}},
#   'MD': {'iso_alpha2': 'MD',
#    'name': 'Moldova',
#    'continent': 'EU',
#    'advisory': {'score': 1.3,
#     'sources_active': 3,
#     'message': 'Moldova has a current risk level of 1.3 (out of 5). We advise: Travelling Moldova is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/moldova'}},
#   'ME': {'iso_alpha2': 'ME',
#    'name': 'Montenegro',
#    'continent': 'EU',
#    'advisory': {'score': 1.3,
#     'sources_active': 3,
#     'message': 'Montenegro has a current risk level of 1.3 (out of 5). We advise: Travelling Montenegro is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/montenegro'}},
#   'MF': {'iso_alpha2': 'MF',
#    'name': 'Saint Martin',
#    'continent': 'NA',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'Saint Martin has a current risk level of 0 (out of 5). We advise: Travelling Saint Martin is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/saint-martin'}},
#   'MG': {'iso_alpha2': 'MG',
#    'name': 'Madagascar',
#    'continent': 'AF',
# ...
#     'message': 'Slovakia has a current risk level of 1.3 (out of 5). We advise: Travelling Slovakia is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/slovakia'}},
#   'SL': {'iso_alpha2': 'SL',
#    'name': 'Sierra Leone',
#    'continent': 'AF',
#    'advisory': {'score': 2.5,
#     'sources_active': 4,
#     'message': 'Sierra Leone has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling Sierra Leone.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/sierra-leone'}},
#   'SM': {'iso_alpha2': 'SM',
#    'name': 'San Marino',
#    'continent': 'EU',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'San Marino has a current risk level of 0 (out of 5). We advise: Travelling San Marino is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/san-marino'}},
#   'SN': {'iso_alpha2': 'SN',
#    'name': 'Senegal',
#    'continent': 'AF',
#    'advisory': {'score': 2.3,
#     'sources_active': 4,
#     'message': 'Senegal has a current risk level of 2.3 (out of 5). We advise: Travelling Senegal is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/senegal'}},
#   'SO': {'iso_alpha2': 'SO',
#    'name': 'Somalia',
#    'continent': 'AF',
#    'advisory': {'score': 5,
#     'sources_active': 8,
#     'message': 'Somalia has a current risk level of 5 (out of 5). We advise: It is not safe to travel Somalia.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/somalia'}},
#   'SR': {'iso_alpha2': 'SR',
#    'name': 'Suriname',
#    'continent': 'SA',
#    'advisory': {'score': 2,
#     'sources_active': 2,
#     'message': 'Suriname has a current risk level of 2 (out of 5). We advise: Travelling Suriname is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/suriname'}},
#   'SS': {'iso_alpha2': 'SS',
#    'name': 'South Sudan',
#    'continent': 'AF',
#    'advisory': {'score': 5,
#     'sources_active': 4,
#     'message': 'South Sudan has a current risk level of 5 (out of 5). We advise: It is not safe to travel South Sudan.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/south-sudan'}},
#   'ST': {'iso_alpha2': 'ST',
#    'name': 'Sao Tome and Principe',
#    'continent': 'AF',
#    'advisory': {'score': 2,
#     'sources_active': 2,
#     'message': 'Sao Tome and Principe has a current risk level of 2 (out of 5). We advise: Travelling Sao Tome and Principe is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/sao-tome-and-principe'}},
#   'SV': {'iso_alpha2': 'SV',
#    'name': 'El Salvador',
#    'continent': 'NA',
#    'advisory': {'score': 2.5,
#     'sources_active': 6,
#     'message': 'El Salvador has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling El Salvador.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/el-salvador'}},
#   'SY': {'iso_alpha2': 'SY',
#    'name': 'Syria',
#    'continent': 'AS',
#    'advisory': {'score': 5,
#     'sources_active': 9,
#     'message': 'Syria has a current risk level of 5 (out of 5). We advise: It is not safe to travel Syria.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/syria'}},
#   'SZ': {'iso_alpha2': 'SZ',
#    'name': 'Swaziland',
#    'continent': 'AF',
#    'advisory': {'score': 2,
#     'sources_active': 3,
#     'message': 'Swaziland has a current risk level of 2 (out of 5). We advise: Travelling Swaziland is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/swaziland'}},
#   'TC': {'iso_alpha2': 'TC',
#    'name': 'Turks and Caicos Islands',
#    'continent': 'NA',
#    'advisory': {'score': 1.5,
#     'sources_active': 2,
#     'message': 'Turks and Caicos Islands has a current risk level of 1.5 (out of 5). We advise: Travelling Turks and Caicos Islands is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/turks-and-caicos-islands'}},
#   'TD': {'iso_alpha2': 'TD',
#    'name': 'Chad',
#    'continent': 'AF',
#    'advisory': {'score': 3.7,
#     'sources_active': 7,
#     'message': 'Chad has a current risk level of 3.7 (out of 5). We advise: Please reconsider your need to travel to Chad.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/chad'}},
#   'TG': {'iso_alpha2': 'TG',
#    'name': 'Togo',
#    'continent': 'AF',
#    'advisory': {'score': 2,
#     'sources_active': 3,
#     'message': 'Togo has a current risk level of 2 (out of 5). We advise: Travelling Togo is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/togo'}},
#   'TH': {'iso_alpha2': 'TH',
#    'name': 'Thailand',
#    'continent': 'AS',
#    'advisory': {'score': 2.1,
#     'sources_active': 7,
#     'message': 'Thailand has a current risk level of 2.1 (out of 5). We advise: Travelling Thailand is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/thailand'}},
#   'TJ': {'iso_alpha2': 'TJ',
#    'name': 'Tajikistan',
#    'continent': 'AS',
#    'advisory': {'score': 2.2,
#     'sources_active': 5,
#     'message': 'Tajikistan has a current risk level of 2.2 (out of 5). We advise: Travelling Tajikistan is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/tajikistan'}},
#   'TL': {'iso_alpha2': 'TL',
#    'name': 'East Timor',
#    'continent': 'OC',
#    'advisory': {'score': 2.6,
#     'sources_active': 5,
#     'message': 'East Timor has a current risk level of 2.6 (out of 5). We advise: Use some caution when travelling East Timor.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/east-timor'}},
#   'TM': {'iso_alpha2': 'TM',
#    'name': 'Turkmenistan',
#    'continent': 'AS',
#    'advisory': {'score': 2.8,
#     'sources_active': 4,
#     'message': 'Turkmenistan has a current risk level of 2.8 (out of 5). We advise: Use some caution when travelling Turkmenistan.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/turkmenistan'}},
#   'TN': {'iso_alpha2': 'TN',
#    'name': 'Tunisia',
#    'continent': 'AF',
#    'advisory': {'score': 2.6,
#     'sources_active': 8,
#     'message': 'Tunisia has a current risk level of 2.6 (out of 5). We advise: Use some caution when travelling Tunisia.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/tunisia'}},
#   'TO': {'iso_alpha2': 'TO',
#    'name': 'Tonga',
#    'continent': 'OC',
#    'advisory': {'score': 1,
#     'sources_active': 1,
#     'message': 'Tonga has a current risk level of 1 (out of 5). We advise: Travelling Tonga is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/tonga'}},
#   'TR': {'iso_alpha2': 'TR',
#    'name': 'Turkey',
#    'continent': 'AS',
#    'advisory': {'score': 2.8,
#     'sources_active': 8,
#     'message': 'Turkey has a current risk level of 2.8 (out of 5). We advise: Use some caution when travelling Turkey.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/turkey'}},
#   'TT': {'iso_alpha2': 'TT',
#    'name': 'Trinidad and Tobago',
#    'continent': 'NA',
#    'advisory': {'score': 2.6,
#     'sources_active': 5,
#     'message': 'Trinidad and Tobago has a current risk level of 2.6 (out of 5). We advise: Use some caution when travelling Trinidad and Tobago.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/trinidad-and-tobago'}},
#   'TV': {'iso_alpha2': 'TV',
#    'name': 'Tuvalu',
#    'continent': 'OC',
#    'advisory': {'score': 1,
#     'sources_active': 1,
#     'message': 'Tuvalu has a current risk level of 1 (out of 5). We advise: Travelling Tuvalu is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/tuvalu'}},
#   'TW': {'iso_alpha2': 'TW',
#    'name': 'Taiwan',
#    'continent': 'AS',
#    'advisory': {'score': 1.5,
#     'sources_active': 2,
#     'message': 'Taiwan has a current risk level of 1.5 (out of 5). We advise: Travelling Taiwan is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/taiwan'}},
#   'TZ': {'iso_alpha2': 'TZ',
#    'name': 'Tanzania',
#    'continent': 'AF',
#    'advisory': {'score': 2.3,
#     'sources_active': 6,
#     'message': 'Tanzania has a current risk level of 2.3 (out of 5). We advise: Travelling Tanzania is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/tanzania'}},
#   'UA': {'iso_alpha2': 'UA',
#    'name': 'Ukraine',
#    'continent': 'EU',
#    'advisory': {'score': 2.8,
#     'sources_active': 9,
#     'message': 'Ukraine has a current risk level of 2.8 (out of 5). We advise: Use some caution when travelling Ukraine.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/ukraine'}},
#   'UG': {'iso_alpha2': 'UG',
#    'name': 'Uganda',
#    'continent': 'AF',
#    'advisory': {'score': 2.7,
#     'sources_active': 6,
#     'message': 'Uganda has a current risk level of 2.7 (out of 5). We advise: Use some caution when travelling Uganda.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/uganda'}},
#   'US': {'iso_alpha2': 'US',
#    'name': 'United States',
#    'continent': 'NA',
#    'advisory': {'score': 1.8,
#     'sources_active': 4,
#     'message': 'United States has a current risk level of 1.8 (out of 5). We advise: Travelling United States is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/united-states'}},
#   'UY': {'iso_alpha2': 'UY',
#    'name': 'Uruguay',
#    'continent': 'SA',
#    'advisory': {'score': 1.7,
#     'sources_active': 3,
#     'message': 'Uruguay has a current risk level of 1.7 (out of 5). We advise: Travelling Uruguay is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/uruguay'}},
#   'UZ': {'iso_alpha2': 'UZ',
#    'name': 'Uzbekistan',
#    'continent': 'AS',
#    'advisory': {'score': 2,
#     'sources_active': 5,
#     'message': 'Uzbekistan has a current risk level of 2 (out of 5). We advise: Travelling Uzbekistan is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/uzbekistan'}},
#   'VA': {'iso_alpha2': 'VA',
#    'name': 'Vatican',
#    'continent': 'EU',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'Vatican has a current risk level of 0 (out of 5). We advise: Travelling Vatican is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/vatican'}},
#   'VC': {'iso_alpha2': 'VC',
#    'name': 'Saint Vincent and the Grenadines',
#    'continent': 'NA',
#    'advisory': {'score': 1,
#     'sources_active': 2,
#     'message': 'Saint Vincent and the Grenadines has a current risk level of 1 (out of 5). We advise: Travelling Saint Vincent and the Grenadines is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/saint-vincent-and-the-grenadines'}},
#   'VE': {'iso_alpha2': 'VE',
#    'name': 'Venezuela',
#    'continent': 'SA',
#    'advisory': {'score': 4.4,
#     'sources_active': 8,
#     'message': 'Venezuela has a current risk level of 4.4 (out of 5). We advise: Please reconsider your need to travel to Venezuela.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/venezuela'}},
#   'VG': {'iso_alpha2': 'VG',
#    'name': 'British Virgin Islands',
#    'continent': 'NA',
#    'advisory': {'score': 1,
#     'sources_active': 2,
#     'message': 'British Virgin Islands has a current risk level of 1 (out of 5). We advise: Travelling British Virgin Islands is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/british-virgin-islands'}},
#   'VI': {'iso_alpha2': 'VI',
#    'name': 'U.S. Virgin Islands',
#    'continent': 'NA',
#    'advisory': {'score': 1,
#     'sources_active': 1,
#     'message': 'U.S. Virgin Islands has a current risk level of 1 (out of 5). We advise: Travelling U.S. Virgin Islands is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/us-virgin-islands'}},
#   'VN': {'iso_alpha2': 'VN',
#    'name': 'Vietnam',
#    'continent': 'AS',
#    'advisory': {'score': 1.8,
#     'sources_active': 5,
#     'message': 'Vietnam has a current risk level of 1.8 (out of 5). We advise: Travelling Vietnam is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/vietnam'}},
#   'VU': {'iso_alpha2': 'VU',
#    'name': 'Vanuatu',
#    'continent': 'OC',
#    'advisory': {'score': 1,
#     'sources_active': 1,
#     'message': 'Vanuatu has a current risk level of 1 (out of 5). We advise: Travelling Vanuatu is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/vanuatu'}},
#   'WF': {'iso_alpha2': 'WF',
#    'name': 'Wallis and Futuna',
#    'continent': 'OC',
#    'advisory': {'score': 0,
#     'sources_active': 0,
#     'message': 'Wallis and Futuna has a current risk level of 0 (out of 5). We advise: Travelling Wallis and Futuna is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/wallis-and-futuna'}},
#   'WS': {'iso_alpha2': 'WS',
#    'name': 'Samoa',
#    'continent': 'OC',
#    'advisory': {'score': 1,
#     'sources_active': 2,
#     'message': 'Samoa has a current risk level of 1 (out of 5). We advise: Travelling Samoa is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/samoa'}},
#   'XK': {'iso_alpha2': 'XK',
#    'name': 'Kosovo',
#    'continent': 'EU',
#    'advisory': {'score': 1.8,
#     'sources_active': 4,
#     'message': 'Kosovo has a current risk level of 1.8 (out of 5). We advise: Travelling Kosovo is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/kosovo'}},
#   'YE': {'iso_alpha2': 'YE',
#    'name': 'Yemen',
#    'continent': 'AS',
#    'advisory': {'score': 5,
#     'sources_active': 9,
#     'message': 'Yemen has a current risk level of 5 (out of 5). We advise: It is not safe to travel Yemen.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/yemen'}},
#   'YT': {'iso_alpha2': 'YT',
#    'name': 'Mayotte',
#    'continent': 'AF',
#    'advisory': {'score': 3,
#     'sources_active': 1,
#     'message': 'Mayotte has a current risk level of 3 (out of 5). We advise: Use some caution when travelling Mayotte.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/mayotte'}},
#   'ZA': {'iso_alpha2': 'ZA',
#    'name': 'South Africa',
#    'continent': 'AF',
#    'advisory': {'score': 2.7,
#     'sources_active': 6,
#     'message': 'South Africa has a current risk level of 2.7 (out of 5). We advise: Use some caution when travelling South Africa.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/south-africa'}},
#   'ZM': {'iso_alpha2': 'ZM',
#    'name': 'Zambia',
#    'continent': 'AF',
#    'advisory': {'score': 2,
#     'sources_active': 3,
#     'message': 'Zambia has a current risk level of 2 (out of 5). We advise: Travelling Zambia is (relatively) safe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/zambia'}},
#   'ZW': {'iso_alpha2': 'ZW',
#    'name': 'Zimbabwe',
#    'continent': 'AF',
#    'advisory': {'score': 2.6,
#     'sources_active': 5,
#     'message': 'Zimbabwe has a current risk level of 2.6 (out of 5). We advise: Use some caution when travelling Zimbabwe.',
#     'updated': '2020-03-07 07:21:16',
#     'source': 'https://www.travel-advisory.info/zimbabwe'}}}}

# %%
#3 - The request seems to give me nested dictionaries as opposed to a JSON file. No problem, I can work with them.
type(ta_json)
# Out:
# dict

# %%
#4 - I locate the dictionary with the relevant data and print it.
ta_json['data']
# Out:
# {'AD': {'iso_alpha2': 'AD',
#   'name': 'Andorra',
#   'continent': 'EU',
#   'advisory': {'score': 1.3,
#    'sources_active': 3,
#    'message': 'Andorra has a current risk level of 1.3 (out of 5). We advise: Travelling Andorra is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/andorra'}},
#  'AE': {'iso_alpha2': 'AE',
#   'name': 'United Arab Emirates',
#   'continent': 'AS',
#   'advisory': {'score': 2.3,
#    'sources_active': 6,
#    'message': 'United Arab Emirates has a current risk level of 2.3 (out of 5). We advise: Travelling United Arab Emirates is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/united-arab-emirates'}},
#  'AF': {'iso_alpha2': 'AF',
#   'name': 'Afghanistan',
#   'continent': 'AS',
#   'advisory': {'score': 5,
#    'sources_active': 10,
#    'message': 'Afghanistan has a current risk level of 5 (out of 5). We advise: It is not safe to travel Afghanistan.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/afghanistan'}},
#  'AG': {'iso_alpha2': 'AG',
#   'name': 'Antigua and Barbuda',
#   'continent': 'NA',
#   'advisory': {'score': 1,
#    'sources_active': 2,
#    'message': 'Antigua and Barbuda has a current risk level of 1 (out of 5). We advise: Travelling Antigua and Barbuda is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/antigua-and-barbuda'}},
#  'AI': {'iso_alpha2': 'AI',
#   'name': 'Anguilla',
#   'continent': 'NA',
#   'advisory': {'score': 1,
#    'sources_active': 2,
#    'message': 'Anguilla has a current risk level of 1 (out of 5). We advise: Travelling Anguilla is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/anguilla'}},
#  'AL': {'iso_alpha2': 'AL',
#   'name': 'Albania',
#   'continent': 'EU',
#   'advisory': {'score': 1.5,
#    'sources_active': 4,
#    'message': 'Albania has a current risk level of 1.5 (out of 5). We advise: Travelling Albania is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/albania'}},
#  'AM': {'iso_alpha2': 'AM',
#   'name': 'Armenia',
#   'continent': 'AS',
#   'advisory': {'score': 1.5,
#    'sources_active': 4,
#    'message': 'Armenia has a current risk level of 1.5 (out of 5). We advise: Travelling Armenia is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/armenia'}},
#  'AO': {'iso_alpha2': 'AO',
#   'name': 'Angola',
#   'continent': 'AF',
#   'advisory': {'score': 2,
#    'sources_active': 5,
#    'message': 'Angola has a current risk level of 2 (out of 5). We advise: Travelling Angola is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/angola'}},
#  'AR': {'iso_alpha2': 'AR',
#   'name': 'Argentina',
#   'continent': 'SA',
#   'advisory': {'score': 1.6,
#    'sources_active': 5,
#    'message': 'Argentina has a current risk level of 1.6 (out of 5). We advise: Travelling Argentina is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/argentina'}},
#  'AS': {'iso_alpha2': 'AS',
#   'name': 'American Samoa',
#   'continent': 'OC',
#   'advisory': {'score': 0,
#    'sources_active': 0,
#    'message': 'American Samoa has a current risk level of 0 (out of 5). We advise: Travelling American Samoa is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/american-samoa'}},
#  'AT': {'iso_alpha2': 'AT',
#   'name': 'Austria',
#   'continent': 'EU',
#   'advisory': {'score': 1.3,
#    'sources_active': 3,
#    'message': 'Austria has a current risk level of 1.3 (out of 5). We advise: Travelling Austria is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/austria'}},
#  'AU': {'iso_alpha2': 'AU',
#   'name': 'Australia',
#   'continent': 'OC',
#   'advisory': {'score': 2,
#    'sources_active': 5,
#    'message': 'Australia has a current risk level of 2 (out of 5). We advise: Travelling Australia is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/australia'}},
#  'AW': {'iso_alpha2': 'AW',
#   'name': 'Aruba',
#   'continent': 'NA',
#   'advisory': {'score': 1,
#    'sources_active': 1,
#    'message': 'Aruba has a current risk level of 1 (out of 5). We advise: Travelling Aruba is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/aruba'}},
#  'AZ': {'iso_alpha2': 'AZ',
#   'name': 'Azerbaijan',
#   'continent': 'AS',
#   'advisory': {'score': 2.6,
#    'sources_active': 5,
#    'message': 'Azerbaijan has a current risk level of 2.6 (out of 5). We advise: Use some caution when travelling Azerbaijan.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/azerbaijan'}},
#  'BA': {'iso_alpha2': 'BA',
#   'name': 'Bosnia and Herzegovina',
#   'continent': 'EU',
#   'advisory': {'score': 2,
#    'sources_active': 4,
#    'message': 'Bosnia and Herzegovina has a current risk level of 2 (out of 5). We advise: Travelling Bosnia and Herzegovina is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/bosnia-and-herzegovina'}},
#  'BB': {'iso_alpha2': 'BB',
#   'name': 'Barbados',
#   'continent': 'NA',
#   'advisory': {'score': 2,
#    'sources_active': 3,
#    'message': 'Barbados has a current risk level of 2 (out of 5). We advise: Travelling Barbados is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/barbados'}},
#  'BD': {'iso_alpha2': 'BD',
#   'name': 'Bangladesh',
#   'continent': 'AS',
#   'advisory': {'score': 2.7,
#    'sources_active': 7,
#    'message': 'Bangladesh has a current risk level of 2.7 (out of 5). We advise: Use some caution when travelling Bangladesh.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/bangladesh'}},
#  'BE': {'iso_alpha2': 'BE',
#   'name': 'Belgium',
#   'continent': 'EU',
#   'advisory': {'score': 2.3,
#    'sources_active': 6,
#    'message': 'Belgium has a current risk level of 2.3 (out of 5). We advise: Travelling Belgium is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/belgium'}},
#  'BF': {'iso_alpha2': 'BF',
#   'name': 'Burkina Faso',
#   'continent': 'AF',
#   'advisory': {'score': 3.8,
#    'sources_active': 8,
#    'message': 'Burkina Faso has a current risk level of 3.8 (out of 5). We advise: Please reconsider your need to travel to Burkina Faso.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/burkina-faso'}},
#  'BG': {'iso_alpha2': 'BG',
#   'name': 'Bulgaria',
#   'continent': 'EU',
#   'advisory': {'score': 1.5,
#    'sources_active': 4,
#    'message': 'Bulgaria has a current risk level of 1.5 (out of 5). We advise: Travelling Bulgaria is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/bulgaria'}},
#  'BH': {'iso_alpha2': 'BH',
#   'name': 'Bahrain',
#   'continent': 'AS',
#   'advisory': {'score': 2.2,
#    'sources_active': 5,
#    'message': 'Bahrain has a current risk level of 2.2 (out of 5). We advise: Travelling Bahrain is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/bahrain'}},
#  'BI': {'iso_alpha2': 'BI',
#   'name': 'Burundi',
#   'continent': 'AF',
#   'advisory': {'score': 4.8,
#    'sources_active': 6,
#    'message': 'Burundi has a current risk level of 4.8 (out of 5). We advise: It is not safe to travel Burundi.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/burundi'}},
#  'BJ': {'iso_alpha2': 'BJ',
#   'name': 'Benin',
#   'continent': 'AF',
#   'advisory': {'score': 2,
#    'sources_active': 3,
#    'message': 'Benin has a current risk level of 2 (out of 5). We advise: Travelling Benin is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/benin'}},
#  'BL': {'iso_alpha2': 'BL',
#   'name': 'Saint Barthélemy',
#   'continent': 'NA',
#   'advisory': {'score': 0,
#    'sources_active': 0,
#    'message': 'Saint Barthélemy has a current risk level of 0 (out of 5). We advise: Travelling Saint Barthélemy is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/saint-barthelemy'}},
#  'BM': {'iso_alpha2': 'BM',
#   'name': 'Bermuda',
#   'continent': 'NA',
#   'advisory': {'score': 1,
#    'sources_active': 2,
#    'message': 'Bermuda has a current risk level of 1 (out of 5). We advise: Travelling Bermuda is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/bermuda'}},
#  'BN': {'iso_alpha2': 'BN',
#   'name': 'Brunei',
#   'continent': 'AS',
#   'advisory': {'score': 1.3,
#    'sources_active': 3,
#    'message': 'Brunei has a current risk level of 1.3 (out of 5). We advise: Travelling Brunei is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/brunei'}},
#  'BO': {'iso_alpha2': 'BO',
#   'name': 'Bolivia',
#   'continent': 'SA',
#   'advisory': {'score': 2.7,
#    'sources_active': 6,
#    'message': 'Bolivia has a current risk level of 2.7 (out of 5). We advise: Use some caution when travelling Bolivia.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/bolivia'}},
#  'BR': {'iso_alpha2': 'BR',
#   'name': 'Brazil',
#   'continent': 'SA',
#   'advisory': {'score': 2.3,
#    'sources_active': 7,
#    'message': 'Brazil has a current risk level of 2.3 (out of 5). We advise: Travelling Brazil is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/brazil'}},
#  'BS': {'iso_alpha2': 'BS',
#   'name': 'Bahamas',
#   'continent': 'NA',
#   'advisory': {'score': 2.3,
#    'sources_active': 4,
#    'message': 'Bahamas has a current risk level of 2.3 (out of 5). We advise: Travelling Bahamas is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/bahamas'}},
#  'BT': {'iso_alpha2': 'BT',
#   'name': 'Bhutan',
#   'continent': 'AS',
#   'advisory': {'score': 1.3,
#    'sources_active': 3,
#    'message': 'Bhutan has a current risk level of 1.3 (out of 5). We advise: Travelling Bhutan is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/bhutan'}},
#  'BW': {'iso_alpha2': 'BW',
#   'name': 'Botswana',
#   'continent': 'AF',
#   'advisory': {'score': 1.3,
#    'sources_active': 3,
#    'message': 'Botswana has a current risk level of 1.3 (out of 5). We advise: Travelling Botswana is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/botswana'}},
#  'BY': {'iso_alpha2': 'BY',
#   'name': 'Belarus',
#   'continent': 'EU',
#   'advisory': {'score': 1.3,
#    'sources_active': 3,
#    'message': 'Belarus has a current risk level of 1.3 (out of 5). We advise: Travelling Belarus is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/belarus'}},
#  'BZ': {'iso_alpha2': 'BZ',
#   'name': 'Belize',
#   'continent': 'NA',
#   'advisory': {'score': 2.4,
#    'sources_active': 5,
#    'message': 'Belize has a current risk level of 2.4 (out of 5). We advise: Travelling Belize is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/belize'}},
#  'CA': {'iso_alpha2': 'CA',
#   'name': 'Canada',
#   'continent': 'NA',
#   'advisory': {'score': 1.5,
#    'sources_active': 4,
#    'message': 'Canada has a current risk level of 1.5 (out of 5). We advise: Travelling Canada is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/canada'}},
#  'CC': {'iso_alpha2': 'CC',
#   'name': 'Cocos Islands',
#   'continent': 'SA',
#   'advisory': {'score': 0,
#    'sources_active': 0,
#    'message': 'Cocos Islands has a current risk level of 0 (out of 5). We advise: Travelling Cocos Islands is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/cocos-islands'}},
#  'CD': {'iso_alpha2': 'CD',
#   'name': 'Democratic Republic of the Congo',
#   'continent': 'AF',
#   'advisory': {'score': 3.8,
#    'sources_active': 8,
#    'message': 'Democratic Republic of the Congo has a current risk level of 3.8 (out of 5). We advise: Please reconsider your need to travel to Democratic Republic of the Congo.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/democratic-republic-of-the-congo'}},
#  'CF': {'iso_alpha2': 'CF',
#   'name': 'Central African Republic',
#   'continent': 'AF',
#   'advisory': {'score': 5,
#    'sources_active': 8,
#    'message': 'Central African Republic has a current risk level of 5 (out of 5). We advise: It is not safe to travel Central African Republic.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/central-african-republic'}},
#  'CG': {'iso_alpha2': 'CG',
#   'name': 'Republic of the Congo',
#   'continent': 'AF',
#   'advisory': {'score': 2.3,
#    'sources_active': 4,
#    'message': 'Republic of the Congo has a current risk level of 2.3 (out of 5). We advise: Travelling Republic of the Congo is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/republic-of-the-congo'}},
#  'CH': {'iso_alpha2': 'CH',
#   'name': 'Switzerland',
#   'continent': 'EU',
#   'advisory': {'score': 1.5,
#    'sources_active': 2,
#    'message': 'Switzerland has a current risk level of 1.5 (out of 5). We advise: Travelling Switzerland is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/switzerland'}},
#  'CI': {'iso_alpha2': 'CI',
#   'name': 'Ivory Coast',
#   'continent': 'AF',
#   'advisory': {'score': 2.7,
#    'sources_active': 6,
#    'message': 'Ivory Coast has a current risk level of 2.7 (out of 5). We advise: Use some caution when travelling Ivory Coast.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/ivory-coast'}},
#  'CK': {'iso_alpha2': 'CK',
#   'name': 'Cook Islands',
#   'continent': 'OC',
#   'advisory': {'score': 0,
#    'sources_active': 0,
#    'message': 'Cook Islands has a current risk level of 0 (out of 5). We advise: Travelling Cook Islands is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/cook-islands'}},
#  'CL': {'iso_alpha2': 'CL',
#   'name': 'Chile',
#   'continent': 'SA',
#   'advisory': {'score': 2.5,
#    'sources_active': 6,
#    'message': 'Chile has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling Chile.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/chile'}},
#  'CM': {'iso_alpha2': 'CM',
#   'name': 'Cameroon',
#   'continent': 'AF',
#   'advisory': {'score': 2.5,
#    'sources_active': 6,
#    'message': 'Cameroon has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling Cameroon.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/cameroon'}},
#  'CN': {'iso_alpha2': 'CN',
#   'name': 'China',
#   'continent': 'AS',
#   'advisory': {'score': 3.9,
#    'sources_active': 9,
#    'message': 'China has a current risk level of 3.9 (out of 5). We advise: Please reconsider your need to travel to China.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/china'}},
#  'CO': {'iso_alpha2': 'CO',
#   'name': 'Colombia',
#   'continent': 'SA',
#   'advisory': {'score': 2.5,
#    'sources_active': 6,
#    'message': 'Colombia has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling Colombia.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/colombia'}},
#  'CR': {'iso_alpha2': 'CR',
#   'name': 'Costa Rica',
#   'continent': 'NA',
#   'advisory': {'score': 2.4,
#    'sources_active': 5,
#    'message': 'Costa Rica has a current risk level of 2.4 (out of 5). We advise: Travelling Costa Rica is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/costa-rica'}},
#  'CU': {'iso_alpha2': 'CU',
#   'name': 'Cuba',
#   'continent': 'NA',
#   'advisory': {'score': 2.3,
#    'sources_active': 3,
#    'message': 'Cuba has a current risk level of 2.3 (out of 5). We advise: Travelling Cuba is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/cuba'}},
#  'CV': {'iso_alpha2': 'CV',
#   'name': 'Cape Verde',
#   'continent': 'AF',
#   'advisory': {'score': 2.3,
#    'sources_active': 4,
#    'message': 'Cape Verde has a current risk level of 2.3 (out of 5). We advise: Travelling Cape Verde is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/cape-verde'}},
#  'CX': {'iso_alpha2': 'CX',
#   'name': 'Christmas Island',
#   'continent': 'OC',
#   'advisory': {'score': 0,
#    'sources_active': 0,
#    'message': 'Christmas Island has a current risk level of 0 (out of 5). We advise: Travelling Christmas Island is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/christmas-island'}},
#  'CY': {'iso_alpha2': 'CY',
#   'name': 'Cyprus',
#   'continent': 'EU',
#   'advisory': {'score': 1.3,
#    'sources_active': 3,
#    'message': 'Cyprus has a current risk level of 1.3 (out of 5). We advise: Travelling Cyprus is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/cyprus'}},
#  'CZ': {'iso_alpha2': 'CZ',
#   'name': 'Czech Republic',
#   'continent': 'EU',
#   'advisory': {'score': 1.5,
#    'sources_active': 4,
#    'message': 'Czech Republic has a current risk level of 1.5 (out of 5). We advise: Travelling Czech Republic is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/czech-republic'}},
#  'DE': {'iso_alpha2': 'DE',
#   'name': 'Germany',
#   'continent': 'EU',
#   'advisory': {'score': 2,
#    'sources_active': 5,
#    'message': 'Germany has a current risk level of 2 (out of 5). We advise: Travelling Germany is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/germany'}},
#  'DJ': {'iso_alpha2': 'DJ',
#   'name': 'Djibouti',
#   'continent': 'AF',
#   'advisory': {'score': 2.2,
#    'sources_active': 5,
#    'message': 'Djibouti has a current risk level of 2.2 (out of 5). We advise: Travelling Djibouti is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/djibouti'}},
#  'DK': {'iso_alpha2': 'DK',
#   'name': 'Denmark',
#   'continent': 'EU',
#   'advisory': {'score': 1.8,
#    'sources_active': 4,
#    'message': 'Denmark has a current risk level of 1.8 (out of 5). We advise: Travelling Denmark is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/denmark'}},
#  'DM': {'iso_alpha2': 'DM',
#   'name': 'Dominica',
#   'continent': 'NA',
#   'advisory': {'score': 2.5,
#    'sources_active': 2,
#    'message': 'Dominica has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling Dominica.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/dominica'}},
#  'DO': {'iso_alpha2': 'DO',
#   'name': 'Dominican Republic',
#   'continent': 'NA',
#   'advisory': {'score': 2.5,
#    'sources_active': 4,
#    'message': 'Dominican Republic has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling Dominican Republic.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/dominican-republic'}},
#  'DZ': {'iso_alpha2': 'DZ',
#   'name': 'Algeria',
#   'continent': 'AF',
#   'advisory': {'score': 2.8,
#    'sources_active': 10,
#    'message': 'Algeria has a current risk level of 2.8 (out of 5). We advise: Use some caution when travelling Algeria.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/algeria'}},
#  'EC': {'iso_alpha2': 'EC',
#   'name': 'Ecuador',
#   'continent': 'SA',
#   'advisory': {'score': 2.5,
#    'sources_active': 6,
#    'message': 'Ecuador has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling Ecuador.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/ecuador'}},
#  'EE': {'iso_alpha2': 'EE',
#   'name': 'Estonia',
#   'continent': 'EU',
#   'advisory': {'score': 1.5,
#    'sources_active': 4,
#    'message': 'Estonia has a current risk level of 1.5 (out of 5). We advise: Travelling Estonia is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/estonia'}},
#  'EG': {'iso_alpha2': 'EG',
#   'name': 'Egypt',
#   'continent': 'AF',
#   'advisory': {'score': 2.8,
#    'sources_active': 10,
#    'message': 'Egypt has a current risk level of 2.8 (out of 5). We advise: Use some caution when travelling Egypt.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/egypt'}},
#  'EH': {'iso_alpha2': 'EH',
#   'name': 'Western Sahara',
#   'continent': 'AF',
#   'advisory': {'score': 0,
#    'sources_active': 0,
#    'message': 'Western Sahara has a current risk level of 0 (out of 5). We advise: Travelling Western Sahara is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/western-sahara'}},
#  'ER': {'iso_alpha2': 'ER',
#   'name': 'Eritrea',
#   'continent': 'AF',
#   'advisory': {'score': 3.3,
#    'sources_active': 7,
#    'message': 'Eritrea has a current risk level of 3.3 (out of 5). We advise: Use some caution when travelling Eritrea.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/eritrea'}},
#  'ES': {'iso_alpha2': 'ES',
#   'name': 'Spain',
#   'continent': 'EU',
#   'advisory': {'score': 2,
#    'sources_active': 5,
#    'message': 'Spain has a current risk level of 2 (out of 5). We advise: Travelling Spain is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/spain'}},
#  'ET': {'iso_alpha2': 'ET',
#   'name': 'Ethiopia',
#   'continent': 'AF',
#   'advisory': {'score': 2.6,
#    'sources_active': 7,
#    'message': 'Ethiopia has a current risk level of 2.6 (out of 5). We advise: Use some caution when travelling Ethiopia.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/ethiopia'}},
#  'FI': {'iso_alpha2': 'FI',
#   'name': 'Finland',
#   'continent': 'EU',
#   'advisory': {'score': 1.3,
#    'sources_active': 3,
#    'message': 'Finland has a current risk level of 1.3 (out of 5). We advise: Travelling Finland is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/finland'}},
#  'FJ': {'iso_alpha2': 'FJ',
#   'name': 'Fiji',
#   'continent': 'OC',
#   'advisory': {'score': 1.3,
#    'sources_active': 3,
#    'message': 'Fiji has a current risk level of 1.3 (out of 5). We advise: Travelling Fiji is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/fiji'}},
#  'FK': {'iso_alpha2': 'FK',
#   'name': 'Falkland Islands',
#   'continent': 'SA',
#   'advisory': {'score': 0,
#    'sources_active': 0,
#    'message': 'Falkland Islands has a current risk level of 0 (out of 5). We advise: Travelling Falkland Islands is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/falkland-islands'}},
#  'FM': {'iso_alpha2': 'FM',
#   'name': 'Micronesia',
#   'continent': 'OC',
#   'advisory': {'score': 1,
#    'sources_active': 1,
#    'message': 'Micronesia has a current risk level of 1 (out of 5). We advise: Travelling Micronesia is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/micronesia'}},
#  'FO': {'iso_alpha2': 'FO',
#   'name': 'Faroe Islands',
#   'continent': 'EU',
#   'advisory': {'score': 0,
#    'sources_active': 0,
#    'message': 'Faroe Islands has a current risk level of 0 (out of 5). We advise: Travelling Faroe Islands is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/faroe-islands'}},
#  'FR': {'iso_alpha2': 'FR',
#   'name': 'France',
#   'continent': 'EU',
#   'advisory': {'score': 2.5,
#    'sources_active': 6,
#    'message': 'France has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling France.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/france'}},
#  'GA': {'iso_alpha2': 'GA',
#   'name': 'Gabon',
#   'continent': 'AF',
#   'advisory': {'score': 2.3,
#    'sources_active': 3,
#    'message': 'Gabon has a current risk level of 2.3 (out of 5). We advise: Travelling Gabon is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/gabon'}},
#  'GB': {'iso_alpha2': 'GB',
#   'name': 'United Kingdom',
#   'continent': 'EU',
#   'advisory': {'score': 2,
#    'sources_active': 6,
#    'message': 'United Kingdom has a current risk level of 2 (out of 5). We advise: Travelling United Kingdom is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/united-kingdom'}},
#  'GD': {'iso_alpha2': 'GD',
#   'name': 'Grenada',
#   'continent': 'NA',
#   'advisory': {'score': 1,
#    'sources_active': 2,
#    'message': 'Grenada has a current risk level of 1 (out of 5). We advise: Travelling Grenada is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/grenada'}},
#  'GE': {'iso_alpha2': 'GE',
#   'name': 'Georgia',
#   'continent': 'AS',
#   'advisory': {'score': 1.3,
#    'sources_active': 3,
#    'message': 'Georgia has a current risk level of 1.3 (out of 5). We advise: Travelling Georgia is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/georgia'}},
#  'GF': {'iso_alpha2': 'GF',
#   'name': 'French Guiana',
#   'continent': 'SA',
#   'advisory': {'score': 3,
#    'sources_active': 1,
#    'message': 'French Guiana has a current risk level of 3 (out of 5). We advise: Use some caution when travelling French Guiana.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/french-guiana'}},
#  'GG': {'iso_alpha2': 'GG',
#   'name': 'Guernsey',
#   'continent': 'EU',
#   'advisory': {'score': 0,
#    'sources_active': 0,
#    'message': 'Guernsey has a current risk level of 0 (out of 5). We advise: Travelling Guernsey is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/guernsey'}},
#  'GH': {'iso_alpha2': 'GH',
#   'name': 'Ghana',
#   'continent': 'AF',
#   'advisory': {'score': 2.5,
#    'sources_active': 4,
#    'message': 'Ghana has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling Ghana.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/ghana'}},
#  'GI': {'iso_alpha2': 'GI',
#   'name': 'Gibraltar',
#   'continent': 'EU',
#   'advisory': {'score': 0,
#    'sources_active': 0,
#    'message': 'Gibraltar has a current risk level of 0 (out of 5). We advise: Travelling Gibraltar is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/gibraltar'}},
#  'GL': {'iso_alpha2': 'GL',
#   'name': 'Greenland',
#   'continent': 'NA',
#   'advisory': {'score': 0,
#    'sources_active': 0,
#    'message': 'Greenland has a current risk level of 0 (out of 5). We advise: Travelling Greenland is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/greenland'}},
#  'GM': {'iso_alpha2': 'GM',
#   'name': 'Gambia',
#   'continent': 'AF',
#   'advisory': {'score': 2.4,
#    'sources_active': 5,
#    'message': 'Gambia has a current risk level of 2.4 (out of 5). We advise: Travelling Gambia is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/gambia'}},
#  'GN': {'iso_alpha2': 'GN',
#   'name': 'Guinea',
#   'continent': 'AF',
#   'advisory': {'score': 2.5,
#    'sources_active': 4,
#    'message': 'Guinea has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling Guinea.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/guinea'}},
#  'GP': {'iso_alpha2': 'GP',
#   'name': 'Guadeloupe',
#   'continent': 'NA',
#   'advisory': {'score': 1,
#    'sources_active': 1,
#    'message': 'Guadeloupe has a current risk level of 1 (out of 5). We advise: Travelling Guadeloupe is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/guadeloupe'}},
#  'GQ': {'iso_alpha2': 'GQ',
#   'name': 'Equatorial Guinea',
#   'continent': 'AF',
#   'advisory': {'score': 2.3,
#    'sources_active': 3,
#    'message': 'Equatorial Guinea has a current risk level of 2.3 (out of 5). We advise: Travelling Equatorial Guinea is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/equatorial-guinea'}},
#  'GR': {'iso_alpha2': 'GR',
#   'name': 'Greece',
#   'continent': 'EU',
#   'advisory': {'score': 1.6,
#    'sources_active': 5,
#    'message': 'Greece has a current risk level of 1.6 (out of 5). We advise: Travelling Greece is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/greece'}},
#  'GS': {'iso_alpha2': 'GS',
#   'name': 'South Georgia and the South Sandwich Islands',
#   'continent': 'AN',
#   'advisory': {'score': 0,
#    'sources_active': 0,
#    'message': 'South Georgia and the South Sandwich Islands has a current risk level of 0 (out of 5). We advise: Travelling South Georgia and the South Sandwich Islands is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/south-georgia-and-the-south-sandwich-islands'}},
#  'GT': {'iso_alpha2': 'GT',
#   'name': 'Guatemala',
#   'continent': 'NA',
#   'advisory': {'score': 2.6,
#    'sources_active': 5,
#    'message': 'Guatemala has a current risk level of 2.6 (out of 5). We advise: Use some caution when travelling Guatemala.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/guatemala'}},
#  'GU': {'iso_alpha2': 'GU',
#   'name': 'Guam',
#   'continent': 'OC',
#   'advisory': {'score': 0,
#    'sources_active': 0,
#    'message': 'Guam has a current risk level of 0 (out of 5). We advise: Travelling Guam is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/guam'}},
#  'GW': {'iso_alpha2': 'GW',
#   'name': 'Guinea-Bissau',
#   'continent': 'AF',
#   'advisory': {'score': 2.7,
#    'sources_active': 3,
#    'message': 'Guinea-Bissau has a current risk level of 2.7 (out of 5). We advise: Use some caution when travelling Guinea-Bissau.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/guinea-bissau'}},
#  'GY': {'iso_alpha2': 'GY',
#   'name': 'Guyana',
#   'continent': 'SA',
#   'advisory': {'score': 2.5,
#    'sources_active': 4,
#    'message': 'Guyana has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling Guyana.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/guyana'}},
#  'HK': {'iso_alpha2': 'HK',
#   'name': 'Hong Kong',
#   'continent': 'AS',
#   'advisory': {'score': 2.6,
#    'sources_active': 5,
#    'message': 'Hong Kong has a current risk level of 2.6 (out of 5). We advise: Use some caution when travelling Hong Kong.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/hong-kong'}},
#  'HN': {'iso_alpha2': 'HN',
#   'name': 'Honduras',
#   'continent': 'NA',
#   'advisory': {'score': 2.8,
#    'sources_active': 5,
#    'message': 'Honduras has a current risk level of 2.8 (out of 5). We advise: Use some caution when travelling Honduras.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/honduras'}},
#  'HR': {'iso_alpha2': 'HR',
#   'name': 'Croatia',
#   'continent': 'EU',
#   'advisory': {'score': 1.5,
#    'sources_active': 4,
#    'message': 'Croatia has a current risk level of 1.5 (out of 5). We advise: Travelling Croatia is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/croatia'}},
#  'HT': {'iso_alpha2': 'HT',
#   'name': 'Haiti',
#   'continent': 'NA',
#   'advisory': {'score': 4.2,
#    'sources_active': 6,
#    'message': 'Haiti has a current risk level of 4.2 (out of 5). We advise: Please reconsider your need to travel to Haiti.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/haiti'}},
#  'HU': {'iso_alpha2': 'HU',
#   'name': 'Hungary',
#   'continent': 'EU',
#   'advisory': {'score': 1.5,
#    'sources_active': 4,
#    'message': 'Hungary has a current risk level of 1.5 (out of 5). We advise: Travelling Hungary is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/hungary'}},
#  'ID': {'iso_alpha2': 'ID',
#   'name': 'Indonesia',
#   'continent': 'AS',
#   'advisory': {'score': 2.5,
#    'sources_active': 6,
#    'message': 'Indonesia has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling Indonesia.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/indonesia'}},
#  'IE': {'iso_alpha2': 'IE',
#   'name': 'Ireland',
#   'continent': 'EU',
#   'advisory': {'score': 1.5,
#    'sources_active': 2,
#    'message': 'Ireland has a current risk level of 1.5 (out of 5). We advise: Travelling Ireland is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/ireland'}},
#  'IL': {'iso_alpha2': 'IL',
#   'name': 'Israel',
#   'continent': 'AS',
#   'advisory': {'score': 2.7,
#    'sources_active': 6,
#    'message': 'Israel has a current risk level of 2.7 (out of 5). We advise: Use some caution when travelling Israel.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/israel'}},
#  'IM': {'iso_alpha2': 'IM',
#   'name': 'Isle of Man',
#   'continent': 'EU',
#   'advisory': {'score': 0,
#    'sources_active': 0,
#    'message': 'Isle of Man has a current risk level of 0 (out of 5). We advise: Travelling Isle of Man is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/isle-of-man'}},
#  'IN': {'iso_alpha2': 'IN',
#   'name': 'India',
#   'continent': 'AS',
#   'advisory': {'score': 2.6,
#    'sources_active': 7,
#    'message': 'India has a current risk level of 2.6 (out of 5). We advise: Use some caution when travelling India.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/india'}},
#  'IQ': {'iso_alpha2': 'IQ',
#   'name': 'Iraq',
#   'continent': 'AS',
#   'advisory': {'score': 4.7,
#    'sources_active': 9,
#    'message': 'Iraq has a current risk level of 4.7 (out of 5). We advise: It is not safe to travel Iraq.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/iraq'}},
#  'IR': {'iso_alpha2': 'IR',
#   'name': 'Iran',
#   'continent': 'AS',
#   'advisory': {'score': 4.6,
#    'sources_active': 7,
#    'message': 'Iran has a current risk level of 4.6 (out of 5). We advise: It is not safe to travel Iran.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/iran'}},
#  'IS': {'iso_alpha2': 'IS',
#   'name': 'Iceland',
#   'continent': 'EU',
#   'advisory': {'score': 1.5,
#    'sources_active': 4,
#    'message': 'Iceland has a current risk level of 1.5 (out of 5). We advise: Travelling Iceland is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/iceland'}},
#  'IT': {'iso_alpha2': 'IT',
#   'name': 'Italy',
#   'continent': 'EU',
#   'advisory': {'score': 3,
#    'sources_active': 7,
#    'message': 'Italy has a current risk level of 3 (out of 5). We advise: Use some caution when travelling Italy.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/italy'}},
#  'JE': {'iso_alpha2': 'JE',
#   'name': 'Jersey',
#   'continent': 'EU',
#   'advisory': {'score': 0,
#    'sources_active': 0,
#    'message': 'Jersey has a current risk level of 0 (out of 5). We advise: Travelling Jersey is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/jersey'}},
#  'JM': {'iso_alpha2': 'JM',
#   'name': 'Jamaica',
#   'continent': 'NA',
#   'advisory': {'score': 2.6,
#    'sources_active': 5,
#    'message': 'Jamaica has a current risk level of 2.6 (out of 5). We advise: Use some caution when travelling Jamaica.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/jamaica'}},
#  'JO': {'iso_alpha2': 'JO',
#   'name': 'Jordan',
#   'continent': 'AS',
#   'advisory': {'score': 2.5,
#    'sources_active': 6,
#    'message': 'Jordan has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling Jordan.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/jordan'}},
#  'JP': {'iso_alpha2': 'JP',
#   'name': 'Japan',
#   'continent': 'AS',
#   'advisory': {'score': 2.1,
#    'sources_active': 7,
#    'message': 'Japan has a current risk level of 2.1 (out of 5). We advise: Travelling Japan is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/japan'}},
#  'KE': {'iso_alpha2': 'KE',
#   'name': 'Kenya',
#   'continent': 'AF',
#   'advisory': {'score': 2.6,
#    'sources_active': 8,
#    'message': 'Kenya has a current risk level of 2.6 (out of 5). We advise: Use some caution when travelling Kenya.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/kenya'}},
#  'KG': {'iso_alpha2': 'KG',
#   'name': 'Kyrgyzstan',
#   'continent': 'AS',
#   'advisory': {'score': 2.2,
#    'sources_active': 5,
#    'message': 'Kyrgyzstan has a current risk level of 2.2 (out of 5). We advise: Travelling Kyrgyzstan is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/kyrgyzstan'}},
#  'KH': {'iso_alpha2': 'KH',
#   'name': 'Cambodia',
#   'continent': 'AS',
#   'advisory': {'score': 2,
#    'sources_active': 5,
#    'message': 'Cambodia has a current risk level of 2 (out of 5). We advise: Travelling Cambodia is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/cambodia'}},
#  'KI': {'iso_alpha2': 'KI',
#   'name': 'Kiribati',
#   'continent': 'OC',
#   'advisory': {'score': 1,
#    'sources_active': 1,
#    'message': 'Kiribati has a current risk level of 1 (out of 5). We advise: Travelling Kiribati is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/kiribati'}},
#  'KM': {'iso_alpha2': 'KM',
#   'name': 'Comoros',
#   'continent': 'AF',
#   'advisory': {'score': 2.3,
#    'sources_active': 3,
#    'message': 'Comoros has a current risk level of 2.3 (out of 5). We advise: Travelling Comoros is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/comoros'}},
#  'KN': {'iso_alpha2': 'KN',
#   'name': 'Saint Kitts and Nevis',
#   'continent': 'NA',
#   'advisory': {'score': 1,
#    'sources_active': 2,
#    'message': 'Saint Kitts and Nevis has a current risk level of 1 (out of 5). We advise: Travelling Saint Kitts and Nevis is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/saint-kitts-and-nevis'}},
#  'KP': {'iso_alpha2': 'KP',
#   'name': 'North Korea',
#   'continent': 'AS',
#   'advisory': {'score': 4.3,
#    'sources_active': 6,
#    'message': 'North Korea has a current risk level of 4.3 (out of 5). We advise: Please reconsider your need to travel to North Korea.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/north-korea'}},
#  'KR': {'iso_alpha2': 'KR',
#   'name': 'South Korea',
#   'continent': 'AS',
#   'advisory': {'score': 2.7,
#    'sources_active': 6,
#    'message': 'South Korea has a current risk level of 2.7 (out of 5). We advise: Use some caution when travelling South Korea.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/south-korea'}},
#  'KW': {'iso_alpha2': 'KW',
#   'name': 'Kuwait',
#   'continent': 'AS',
#   'advisory': {'score': 2,
#    'sources_active': 5,
#    'message': 'Kuwait has a current risk level of 2 (out of 5). We advise: Travelling Kuwait is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/kuwait'}},
#  'KY': {'iso_alpha2': 'KY',
#   'name': 'Cayman Islands',
#   'continent': 'NA',
#   'advisory': {'score': 1,
#    'sources_active': 2,
#    'message': 'Cayman Islands has a current risk level of 1 (out of 5). We advise: Travelling Cayman Islands is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/cayman-islands'}},
#  'KZ': {'iso_alpha2': 'KZ',
#   'name': 'Kazakhstan',
#   'continent': 'AS',
#   'advisory': {'score': 2.2,
#    'sources_active': 5,
#    'message': 'Kazakhstan has a current risk level of 2.2 (out of 5). We advise: Travelling Kazakhstan is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/kazakhstan'}},
#  'LA': {'iso_alpha2': 'LA',
#   'name': 'Laos',
#   'continent': 'AS',
#   'advisory': {'score': 1.5,
#    'sources_active': 4,
#    'message': 'Laos has a current risk level of 1.5 (out of 5). We advise: Travelling Laos is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/laos'}},
#  'LB': {'iso_alpha2': 'LB',
#   'name': 'Lebanon',
#   'continent': 'AS',
#   'advisory': {'score': 2.9,
#    'sources_active': 9,
#    'message': 'Lebanon has a current risk level of 2.9 (out of 5). We advise: Use some caution when travelling Lebanon.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/lebanon'}},
#  'LC': {'iso_alpha2': 'LC',
#   'name': 'Saint Lucia',
#   'continent': 'NA',
#   'advisory': {'score': 1,
#    'sources_active': 2,
#    'message': 'Saint Lucia has a current risk level of 1 (out of 5). We advise: Travelling Saint Lucia is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/saint-lucia'}},
#  'LI': {'iso_alpha2': 'LI',
#   'name': 'Liechtenstein',
#   'continent': 'EU',
#   'advisory': {'score': 1.3,
#    'sources_active': 3,
#    'message': 'Liechtenstein has a current risk level of 1.3 (out of 5). We advise: Travelling Liechtenstein is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/liechtenstein'}},
#  'LK': {'iso_alpha2': 'LK',
#   'name': 'Sri Lanka',
#   'continent': 'AS',
#   'advisory': {'score': 2.7,
#    'sources_active': 7,
#    'message': 'Sri Lanka has a current risk level of 2.7 (out of 5). We advise: Use some caution when travelling Sri Lanka.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/sri-lanka'}},
#  'LR': {'iso_alpha2': 'LR',
#   'name': 'Liberia',
#   'continent': 'AF',
#   'advisory': {'score': 2.3,
#    'sources_active': 4,
#    'message': 'Liberia has a current risk level of 2.3 (out of 5). We advise: Travelling Liberia is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/liberia'}},
#  'LS': {'iso_alpha2': 'LS',
#   'name': 'Lesotho',
#   'continent': 'AF',
#   'advisory': {'score': 2.3,
#    'sources_active': 4,
#    'message': 'Lesotho has a current risk level of 2.3 (out of 5). We advise: Travelling Lesotho is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/lesotho'}},
#  'LT': {'iso_alpha2': 'LT',
#   'name': 'Lithuania',
#   'continent': 'EU',
#   'advisory': {'score': 1.5,
#    'sources_active': 4,
#    'message': 'Lithuania has a current risk level of 1.5 (out of 5). We advise: Travelling Lithuania is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/lithuania'}},
#  'LU': {'iso_alpha2': 'LU',
#   'name': 'Luxembourg',
#   'continent': 'EU',
#   'advisory': {'score': 1.3,
#    'sources_active': 3,
#    'message': 'Luxembourg has a current risk level of 1.3 (out of 5). We advise: Travelling Luxembourg is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/luxembourg'}},
#  'LV': {'iso_alpha2': 'LV',
#   'name': 'Latvia',
#   'continent': 'EU',
#   'advisory': {'score': 1.5,
#    'sources_active': 4,
#    'message': 'Latvia has a current risk level of 1.5 (out of 5). We advise: Travelling Latvia is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/latvia'}},
#  'LY': {'iso_alpha2': 'LY',
#   'name': 'Libya',
#   'continent': 'AF',
#   'advisory': {'score': 5,
#    'sources_active': 9,
#    'message': 'Libya has a current risk level of 5 (out of 5). We advise: It is not safe to travel Libya.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/libya'}},
#  'MA': {'iso_alpha2': 'MA',
#   'name': 'Morocco',
#   'continent': 'AF',
#   'advisory': {'score': 2.4,
#    'sources_active': 7,
#    'message': 'Morocco has a current risk level of 2.4 (out of 5). We advise: Travelling Morocco is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/morocco'}},
#  'MC': {'iso_alpha2': 'MC',
#   'name': 'Monaco',
#   'continent': 'EU',
#   'advisory': {'score': 1.5,
#    'sources_active': 2,
#    'message': 'Monaco has a current risk level of 1.5 (out of 5). We advise: Travelling Monaco is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/monaco'}},
#  'MD': {'iso_alpha2': 'MD',
#   'name': 'Moldova',
#   'continent': 'EU',
#   'advisory': {'score': 1.3,
#    'sources_active': 3,
#    'message': 'Moldova has a current risk level of 1.3 (out of 5). We advise: Travelling Moldova is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/moldova'}},
#  'ME': {'iso_alpha2': 'ME',
#   'name': 'Montenegro',
#   'continent': 'EU',
#   'advisory': {'score': 1.3,
#    'sources_active': 3,
#    'message': 'Montenegro has a current risk level of 1.3 (out of 5). We advise: Travelling Montenegro is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/montenegro'}},
#  'MF': {'iso_alpha2': 'MF',
#   'name': 'Saint Martin',
#   'continent': 'NA',
#   'advisory': {'score': 0,
#    'sources_active': 0,
#    'message': 'Saint Martin has a current risk level of 0 (out of 5). We advise: Travelling Saint Martin is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/saint-martin'}},
#  'MG': {'iso_alpha2': 'MG',
#   'name': 'Madagascar',
#   'continent': 'AF',
#   'advisory': {'score': 2.5,
#    'sources_active': 6,
#    'message': 'Madagascar has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling Madagascar.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/madagascar'}},
#  'MH': {'iso_alpha2': 'MH',
#   'name': 'Marshall Islands',
#   'continent': 'OC',
#   'advisory': {'score': 1,
#    'sources_active': 1,
#    'message': 'Marshall Islands has a current risk level of 1 (out of 5). We advise: Travelling Marshall Islands is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/marshall-islands'}},
#  'MK': {'iso_alpha2': 'MK',
#   'name': 'Macedonia',
#   'continent': 'EU',
#   'advisory': {'score': 1.3,
#    'sources_active': 3,
#    'message': 'Macedonia has a current risk level of 1.3 (out of 5). We advise: Travelling Macedonia is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/macedonia'}},
#  'ML': {'iso_alpha2': 'ML',
#   'name': 'Mali',
#   'continent': 'AF',
#   'advisory': {'score': 4.7,
#    'sources_active': 9,
#    'message': 'Mali has a current risk level of 4.7 (out of 5). We advise: It is not safe to travel Mali.',
#    'updated': '2020-03-07 07:21:16',
# ...
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/svalbard-and-jan-mayen'}},
#  'SK': {'iso_alpha2': 'SK',
#   'name': 'Slovakia',
#   'continent': 'EU',
#   'advisory': {'score': 1.3,
#    'sources_active': 3,
#    'message': 'Slovakia has a current risk level of 1.3 (out of 5). We advise: Travelling Slovakia is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/slovakia'}},
#  'SL': {'iso_alpha2': 'SL',
#   'name': 'Sierra Leone',
#   'continent': 'AF',
#   'advisory': {'score': 2.5,
#    'sources_active': 4,
#    'message': 'Sierra Leone has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling Sierra Leone.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/sierra-leone'}},
#  'SM': {'iso_alpha2': 'SM',
#   'name': 'San Marino',
#   'continent': 'EU',
#   'advisory': {'score': 0,
#    'sources_active': 0,
#    'message': 'San Marino has a current risk level of 0 (out of 5). We advise: Travelling San Marino is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/san-marino'}},
#  'SN': {'iso_alpha2': 'SN',
#   'name': 'Senegal',
#   'continent': 'AF',
#   'advisory': {'score': 2.3,
#    'sources_active': 4,
#    'message': 'Senegal has a current risk level of 2.3 (out of 5). We advise: Travelling Senegal is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/senegal'}},
#  'SO': {'iso_alpha2': 'SO',
#   'name': 'Somalia',
#   'continent': 'AF',
#   'advisory': {'score': 5,
#    'sources_active': 8,
#    'message': 'Somalia has a current risk level of 5 (out of 5). We advise: It is not safe to travel Somalia.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/somalia'}},
#  'SR': {'iso_alpha2': 'SR',
#   'name': 'Suriname',
#   'continent': 'SA',
#   'advisory': {'score': 2,
#    'sources_active': 2,
#    'message': 'Suriname has a current risk level of 2 (out of 5). We advise: Travelling Suriname is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/suriname'}},
#  'SS': {'iso_alpha2': 'SS',
#   'name': 'South Sudan',
#   'continent': 'AF',
#   'advisory': {'score': 5,
#    'sources_active': 4,
#    'message': 'South Sudan has a current risk level of 5 (out of 5). We advise: It is not safe to travel South Sudan.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/south-sudan'}},
#  'ST': {'iso_alpha2': 'ST',
#   'name': 'Sao Tome and Principe',
#   'continent': 'AF',
#   'advisory': {'score': 2,
#    'sources_active': 2,
#    'message': 'Sao Tome and Principe has a current risk level of 2 (out of 5). We advise: Travelling Sao Tome and Principe is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/sao-tome-and-principe'}},
#  'SV': {'iso_alpha2': 'SV',
#   'name': 'El Salvador',
#   'continent': 'NA',
#   'advisory': {'score': 2.5,
#    'sources_active': 6,
#    'message': 'El Salvador has a current risk level of 2.5 (out of 5). We advise: Use some caution when travelling El Salvador.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/el-salvador'}},
#  'SY': {'iso_alpha2': 'SY',
#   'name': 'Syria',
#   'continent': 'AS',
#   'advisory': {'score': 5,
#    'sources_active': 9,
#    'message': 'Syria has a current risk level of 5 (out of 5). We advise: It is not safe to travel Syria.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/syria'}},
#  'SZ': {'iso_alpha2': 'SZ',
#   'name': 'Swaziland',
#   'continent': 'AF',
#   'advisory': {'score': 2,
#    'sources_active': 3,
#    'message': 'Swaziland has a current risk level of 2 (out of 5). We advise: Travelling Swaziland is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/swaziland'}},
#  'TC': {'iso_alpha2': 'TC',
#   'name': 'Turks and Caicos Islands',
#   'continent': 'NA',
#   'advisory': {'score': 1.5,
#    'sources_active': 2,
#    'message': 'Turks and Caicos Islands has a current risk level of 1.5 (out of 5). We advise: Travelling Turks and Caicos Islands is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/turks-and-caicos-islands'}},
#  'TD': {'iso_alpha2': 'TD',
#   'name': 'Chad',
#   'continent': 'AF',
#   'advisory': {'score': 3.7,
#    'sources_active': 7,
#    'message': 'Chad has a current risk level of 3.7 (out of 5). We advise: Please reconsider your need to travel to Chad.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/chad'}},
#  'TG': {'iso_alpha2': 'TG',
#   'name': 'Togo',
#   'continent': 'AF',
#   'advisory': {'score': 2,
#    'sources_active': 3,
#    'message': 'Togo has a current risk level of 2 (out of 5). We advise: Travelling Togo is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/togo'}},
#  'TH': {'iso_alpha2': 'TH',
#   'name': 'Thailand',
#   'continent': 'AS',
#   'advisory': {'score': 2.1,
#    'sources_active': 7,
#    'message': 'Thailand has a current risk level of 2.1 (out of 5). We advise: Travelling Thailand is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/thailand'}},
#  'TJ': {'iso_alpha2': 'TJ',
#   'name': 'Tajikistan',
#   'continent': 'AS',
#   'advisory': {'score': 2.2,
#    'sources_active': 5,
#    'message': 'Tajikistan has a current risk level of 2.2 (out of 5). We advise: Travelling Tajikistan is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/tajikistan'}},
#  'TL': {'iso_alpha2': 'TL',
#   'name': 'East Timor',
#   'continent': 'OC',
#   'advisory': {'score': 2.6,
#    'sources_active': 5,
#    'message': 'East Timor has a current risk level of 2.6 (out of 5). We advise: Use some caution when travelling East Timor.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/east-timor'}},
#  'TM': {'iso_alpha2': 'TM',
#   'name': 'Turkmenistan',
#   'continent': 'AS',
#   'advisory': {'score': 2.8,
#    'sources_active': 4,
#    'message': 'Turkmenistan has a current risk level of 2.8 (out of 5). We advise: Use some caution when travelling Turkmenistan.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/turkmenistan'}},
#  'TN': {'iso_alpha2': 'TN',
#   'name': 'Tunisia',
#   'continent': 'AF',
#   'advisory': {'score': 2.6,
#    'sources_active': 8,
#    'message': 'Tunisia has a current risk level of 2.6 (out of 5). We advise: Use some caution when travelling Tunisia.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/tunisia'}},
#  'TO': {'iso_alpha2': 'TO',
#   'name': 'Tonga',
#   'continent': 'OC',
#   'advisory': {'score': 1,
#    'sources_active': 1,
#    'message': 'Tonga has a current risk level of 1 (out of 5). We advise: Travelling Tonga is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/tonga'}},
#  'TR': {'iso_alpha2': 'TR',
#   'name': 'Turkey',
#   'continent': 'AS',
#   'advisory': {'score': 2.8,
#    'sources_active': 8,
#    'message': 'Turkey has a current risk level of 2.8 (out of 5). We advise: Use some caution when travelling Turkey.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/turkey'}},
#  'TT': {'iso_alpha2': 'TT',
#   'name': 'Trinidad and Tobago',
#   'continent': 'NA',
#   'advisory': {'score': 2.6,
#    'sources_active': 5,
#    'message': 'Trinidad and Tobago has a current risk level of 2.6 (out of 5). We advise: Use some caution when travelling Trinidad and Tobago.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/trinidad-and-tobago'}},
#  'TV': {'iso_alpha2': 'TV',
#   'name': 'Tuvalu',
#   'continent': 'OC',
#   'advisory': {'score': 1,
#    'sources_active': 1,
#    'message': 'Tuvalu has a current risk level of 1 (out of 5). We advise: Travelling Tuvalu is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/tuvalu'}},
#  'TW': {'iso_alpha2': 'TW',
#   'name': 'Taiwan',
#   'continent': 'AS',
#   'advisory': {'score': 1.5,
#    'sources_active': 2,
#    'message': 'Taiwan has a current risk level of 1.5 (out of 5). We advise: Travelling Taiwan is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/taiwan'}},
#  'TZ': {'iso_alpha2': 'TZ',
#   'name': 'Tanzania',
#   'continent': 'AF',
#   'advisory': {'score': 2.3,
#    'sources_active': 6,
#    'message': 'Tanzania has a current risk level of 2.3 (out of 5). We advise: Travelling Tanzania is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/tanzania'}},
#  'UA': {'iso_alpha2': 'UA',
#   'name': 'Ukraine',
#   'continent': 'EU',
#   'advisory': {'score': 2.8,
#    'sources_active': 9,
#    'message': 'Ukraine has a current risk level of 2.8 (out of 5). We advise: Use some caution when travelling Ukraine.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/ukraine'}},
#  'UG': {'iso_alpha2': 'UG',
#   'name': 'Uganda',
#   'continent': 'AF',
#   'advisory': {'score': 2.7,
#    'sources_active': 6,
#    'message': 'Uganda has a current risk level of 2.7 (out of 5). We advise: Use some caution when travelling Uganda.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/uganda'}},
#  'US': {'iso_alpha2': 'US',
#   'name': 'United States',
#   'continent': 'NA',
#   'advisory': {'score': 1.8,
#    'sources_active': 4,
#    'message': 'United States has a current risk level of 1.8 (out of 5). We advise: Travelling United States is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/united-states'}},
#  'UY': {'iso_alpha2': 'UY',
#   'name': 'Uruguay',
#   'continent': 'SA',
#   'advisory': {'score': 1.7,
#    'sources_active': 3,
#    'message': 'Uruguay has a current risk level of 1.7 (out of 5). We advise: Travelling Uruguay is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/uruguay'}},
#  'UZ': {'iso_alpha2': 'UZ',
#   'name': 'Uzbekistan',
#   'continent': 'AS',
#   'advisory': {'score': 2,
#    'sources_active': 5,
#    'message': 'Uzbekistan has a current risk level of 2 (out of 5). We advise: Travelling Uzbekistan is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/uzbekistan'}},
#  'VA': {'iso_alpha2': 'VA',
#   'name': 'Vatican',
#   'continent': 'EU',
#   'advisory': {'score': 0,
#    'sources_active': 0,
#    'message': 'Vatican has a current risk level of 0 (out of 5). We advise: Travelling Vatican is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/vatican'}},
#  'VC': {'iso_alpha2': 'VC',
#   'name': 'Saint Vincent and the Grenadines',
#   'continent': 'NA',
#   'advisory': {'score': 1,
#    'sources_active': 2,
#    'message': 'Saint Vincent and the Grenadines has a current risk level of 1 (out of 5). We advise: Travelling Saint Vincent and the Grenadines is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/saint-vincent-and-the-grenadines'}},
#  'VE': {'iso_alpha2': 'VE',
#   'name': 'Venezuela',
#   'continent': 'SA',
#   'advisory': {'score': 4.4,
#    'sources_active': 8,
#    'message': 'Venezuela has a current risk level of 4.4 (out of 5). We advise: Please reconsider your need to travel to Venezuela.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/venezuela'}},
#  'VG': {'iso_alpha2': 'VG',
#   'name': 'British Virgin Islands',
#   'continent': 'NA',
#   'advisory': {'score': 1,
#    'sources_active': 2,
#    'message': 'British Virgin Islands has a current risk level of 1 (out of 5). We advise: Travelling British Virgin Islands is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/british-virgin-islands'}},
#  'VI': {'iso_alpha2': 'VI',
#   'name': 'U.S. Virgin Islands',
#   'continent': 'NA',
#   'advisory': {'score': 1,
#    'sources_active': 1,
#    'message': 'U.S. Virgin Islands has a current risk level of 1 (out of 5). We advise: Travelling U.S. Virgin Islands is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/us-virgin-islands'}},
#  'VN': {'iso_alpha2': 'VN',
#   'name': 'Vietnam',
#   'continent': 'AS',
#   'advisory': {'score': 1.8,
#    'sources_active': 5,
#    'message': 'Vietnam has a current risk level of 1.8 (out of 5). We advise: Travelling Vietnam is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/vietnam'}},
#  'VU': {'iso_alpha2': 'VU',
#   'name': 'Vanuatu',
#   'continent': 'OC',
#   'advisory': {'score': 1,
#    'sources_active': 1,
#    'message': 'Vanuatu has a current risk level of 1 (out of 5). We advise: Travelling Vanuatu is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/vanuatu'}},
#  'WF': {'iso_alpha2': 'WF',
#   'name': 'Wallis and Futuna',
#   'continent': 'OC',
#   'advisory': {'score': 0,
#    'sources_active': 0,
#    'message': 'Wallis and Futuna has a current risk level of 0 (out of 5). We advise: Travelling Wallis and Futuna is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/wallis-and-futuna'}},
#  'WS': {'iso_alpha2': 'WS',
#   'name': 'Samoa',
#   'continent': 'OC',
#   'advisory': {'score': 1,
#    'sources_active': 2,
#    'message': 'Samoa has a current risk level of 1 (out of 5). We advise: Travelling Samoa is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/samoa'}},
#  'XK': {'iso_alpha2': 'XK',
#   'name': 'Kosovo',
#   'continent': 'EU',
#   'advisory': {'score': 1.8,
#    'sources_active': 4,
#    'message': 'Kosovo has a current risk level of 1.8 (out of 5). We advise: Travelling Kosovo is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/kosovo'}},
#  'YE': {'iso_alpha2': 'YE',
#   'name': 'Yemen',
#   'continent': 'AS',
#   'advisory': {'score': 5,
#    'sources_active': 9,
#    'message': 'Yemen has a current risk level of 5 (out of 5). We advise: It is not safe to travel Yemen.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/yemen'}},
#  'YT': {'iso_alpha2': 'YT',
#   'name': 'Mayotte',
#   'continent': 'AF',
#   'advisory': {'score': 3,
#    'sources_active': 1,
#    'message': 'Mayotte has a current risk level of 3 (out of 5). We advise: Use some caution when travelling Mayotte.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/mayotte'}},
#  'ZA': {'iso_alpha2': 'ZA',
#   'name': 'South Africa',
#   'continent': 'AF',
#   'advisory': {'score': 2.7,
#    'sources_active': 6,
#    'message': 'South Africa has a current risk level of 2.7 (out of 5). We advise: Use some caution when travelling South Africa.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/south-africa'}},
#  'ZM': {'iso_alpha2': 'ZM',
#   'name': 'Zambia',
#   'continent': 'AF',
#   'advisory': {'score': 2,
#    'sources_active': 3,
#    'message': 'Zambia has a current risk level of 2 (out of 5). We advise: Travelling Zambia is (relatively) safe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/zambia'}},
#  'ZW': {'iso_alpha2': 'ZW',
#   'name': 'Zimbabwe',
#   'continent': 'AF',
#   'advisory': {'score': 2.6,
#    'sources_active': 5,
#    'message': 'Zimbabwe has a current risk level of 2.6 (out of 5). We advise: Use some caution when travelling Zimbabwe.',
#    'updated': '2020-03-07 07:21:16',
#    'source': 'https://www.travel-advisory.info/zimbabwe'}}}

# %% [markdown]
# ### II. Wrangling

# %%
#5 - I convert my dictionary into a data frame and export it as my 'raw' .csv file.

ta_df = pd.DataFrame(ta_json['data'])
ta_df.to_csv('/Users/alejandroarrya/Desktop/Ironhack/DAFTMX/web-project/Data/api_raw.csv')

# %%
#6 - I apply '.transpose()' for better readability. I also change the indeces in my data frame to 
#be numbers as opposed to the ISO country codes. This will be important later on when I merge data frames.

ta_df.columns = [x for x in range(len(ta_df.columns))]
ta_df = ta_df.transpose()
ta_df.head()
# Out:
#                                             advisory continent iso_alpha2  \
# 0  {'score': 1.3, 'sources_active': 3, 'message':...        EU         AD
# 1  {'score': 2.3, 'sources_active': 6, 'message':...        AS         AE
# 2  {'score': 5, 'sources_active': 10, 'message': ...        AS         AF
# 3  {'score': 1, 'sources_active': 2, 'message': '...        NA         AG
# 4  {'score': 1, 'sources_active': 2, 'message': '...        NA         AI
#
#                    name
# 0               Andorra
# 1  United Arab Emirates
# 2           Afghanistan
# 3   Antigua and Barbuda
# 4              Anguilla

# %%
#7 - It seems I have nested dictionaries within my advisory column. I expand them and create a new data frame

advisory_columns = [dictionary.keys() for dictionary in ta_df['advisory']][0]
advisory_indeces = [dictionary.values() for dictionary in ta_df['advisory']]
advisory_df = pd.DataFrame(advisory_indeces, columns=advisory_columns)
advisory_df.head()
# Out:
#    score  sources_active                                            message  \
# 0    1.3               3  Andorra has a current risk level of 1.3 (out o...
# 1    2.3               6  United Arab Emirates has a current risk level ...
# 2    5.0              10  Afghanistan has a current risk level of 5 (out...
# 3    1.0               2  Antigua and Barbuda has a current risk level o...
# 4    1.0               2  Anguilla has a current risk level of 1 (out of...
#
#                updated                                             source
# 0  2020-03-07 07:21:16           https://www.travel-advisory.info/andorra
# 1  2020-03-07 07:21:16  https://www.travel-advisory.info/united-arab-e...
# 2  2020-03-07 07:21:16       https://www.travel-advisory.info/afghanistan
# 3  2020-03-07 07:21:16  https://www.travel-advisory.info/antigua-and-b...
# 4  2020-03-07 07:21:16          https://www.travel-advisory.info/anguilla

# %%
#8 - I concatenate my two data frames and drop the unnecessary columns.

main_df = pd.concat([advisory_df, ta_df], axis=1)

columns_to_drop = ['advisory', 'message','sources_active']
main_df = main_df.drop(columns_to_drop, axis=1)

main_df.head()
# Out:
#    score              updated  \
# 0    1.3  2020-03-07 07:21:16
# 1    2.3  2020-03-07 07:21:16
# 2    5.0  2020-03-07 07:21:16
# 3    1.0  2020-03-07 07:21:16
# 4    1.0  2020-03-07 07:21:16
#
#                                               source continent iso_alpha2  \
# 0           https://www.travel-advisory.info/andorra        EU         AD
# 1  https://www.travel-advisory.info/united-arab-e...        AS         AE
# 2       https://www.travel-advisory.info/afghanistan        AS         AF
# 3  https://www.travel-advisory.info/antigua-and-b...        NA         AG
# 4          https://www.travel-advisory.info/anguilla        NA         AI
#
#                    name
# 0               Andorra
# 1  United Arab Emirates
# 2           Afghanistan
# 3   Antigua and Barbuda
# 4              Anguilla

# %%
#9 - I change values in 'continent' for improved readability.

main_df['continent'] = main_df.continent.replace('EU', 'Europe').replace('AF', 'Africa').replace('NA', 'North America').replace('SA', 'South America').replace('AS', 'Asia').replace('AN', 'Antarctica').replace('OC', 'Oceania')
main_df.head()
# Out:
#    score              updated  \
# 0    1.3  2020-03-07 07:21:16
# 1    2.3  2020-03-07 07:21:16
# 2    5.0  2020-03-07 07:21:16
# 3    1.0  2020-03-07 07:21:16
# 4    1.0  2020-03-07 07:21:16
#
#                                               source      continent  \
# 0           https://www.travel-advisory.info/andorra         Europe
# 1  https://www.travel-advisory.info/united-arab-e...           Asia
# 2       https://www.travel-advisory.info/afghanistan           Asia
# 3  https://www.travel-advisory.info/antigua-and-b...  North America
# 4          https://www.travel-advisory.info/anguilla  North America
#
#   iso_alpha2                  name
# 0         AD               Andorra
# 1         AE  United Arab Emirates
# 2         AF           Afghanistan
# 3         AG   Antigua and Barbuda
# 4         AI              Anguilla

# %%
#10 - I need to express each country's 'score' in a better, clearer way. I shall use bins. First, I need to 
#check what's the min and max for that column.

print(main_df['score'].max())
print(main_df['score'].min())
# Out:
# 5.0
# 0.0

# %%
#11 - I will create a new column to bin the numeric scores.

safety_labels = ['Extremely Safe','Safe','Caution','Dangerous','Extremely Dangerous']

bins = pd.cut(main_df['score'],5, labels=safety_labels)
main_df['status'] = bins
main_df.head()
# Out:
#    score              updated  \
# 0    1.3  2020-03-07 07:21:16
# 1    2.3  2020-03-07 07:21:16
# 2    5.0  2020-03-07 07:21:16
# 3    1.0  2020-03-07 07:21:16
# 4    1.0  2020-03-07 07:21:16
#
#                                               source      continent  \
# 0           https://www.travel-advisory.info/andorra         Europe
# 1  https://www.travel-advisory.info/united-arab-e...           Asia
# 2       https://www.travel-advisory.info/afghanistan           Asia
# 3  https://www.travel-advisory.info/antigua-and-b...  North America
# 4          https://www.travel-advisory.info/anguilla  North America
#
#   iso_alpha2                  name               status
# 0         AD               Andorra                 Safe
# 1         AE  United Arab Emirates              Caution
# 2         AF           Afghanistan  Extremely Dangerous
# 3         AG   Antigua and Barbuda       Extremely Safe
# 4         AI              Anguilla       Extremely Safe

# %%
#12 - I will reorder the columns.

column_order = [
    'name',
    'iso_alpha2',
    'continent',
    'score',
    'status',
    'updated',
    'source'
]

main_df = main_df[column_order]

# %%
#13 - I will rename the columns.

main_df.columns = [
    'Name',
    'ISO',
    'Continent',
    'Score',
    'Status',
    'Last Update',
    'Source'
]

main_df.head()
# Out:
#                    Name ISO      Continent  Score               Status  \
# 0               Andorra  AD         Europe    1.3                 Safe
# 1  United Arab Emirates  AE           Asia    2.3              Caution
# 2           Afghanistan  AF           Asia    5.0  Extremely Dangerous
# 3   Antigua and Barbuda  AG  North America    1.0       Extremely Safe
# 4              Anguilla  AI  North America    1.0       Extremely Safe
#
#            Last Update                                             Source
# 0  2020-03-07 07:21:16           https://www.travel-advisory.info/andorra
# 1  2020-03-07 07:21:16  https://www.travel-advisory.info/united-arab-e...
# 2  2020-03-07 07:21:16       https://www.travel-advisory.info/afghanistan
# 3  2020-03-07 07:21:16  https://www.travel-advisory.info/antigua-and-b...
# 4  2020-03-07 07:21:16          https://www.travel-advisory.info/anguilla

# %% [markdown]
# ### III. Analysis

# %%
#14 - I will sort my data frame to find the top 10 most dangerous countries.

all_dangerous = main_df.sort_values('Score', ascending=False).head(10)
all_dangerous
# Out:
#                          Name ISO Continent  Score               Status  \
# 36   Central African Republic  CF    Africa    5.0  Extremely Dangerous
# 2                 Afghanistan  AF      Asia    5.0  Extremely Dangerous
# 233                     Yemen  YE      Asia    5.0  Extremely Dangerous
# 197                   Somalia  SO    Africa    5.0  Extremely Dangerous
# 199               South Sudan  SS    Africa    5.0  Extremely Dangerous
# 128                     Libya  LY    Africa    5.0  Extremely Dangerous
# 202                     Syria  SY      Asia    5.0  Extremely Dangerous
# 21                    Burundi  BI    Africa    4.8  Extremely Dangerous
# 137                      Mali  ML    Africa    4.7  Extremely Dangerous
# 99                       Iraq  IQ      Asia    4.7  Extremely Dangerous
#
#              Last Update                                             Source
# 36   2020-03-07 07:21:16  https://www.travel-advisory.info/central-afric...
# 2    2020-03-07 07:21:16       https://www.travel-advisory.info/afghanistan
# 233  2020-03-07 07:21:16             https://www.travel-advisory.info/yemen
# 197  2020-03-07 07:21:16           https://www.travel-advisory.info/somalia
# 199  2020-03-07 07:21:16       https://www.travel-advisory.info/south-sudan
# 128  2020-03-07 07:21:16             https://www.travel-advisory.info/libya
# 202  2020-03-07 07:21:16             https://www.travel-advisory.info/syria
# 21   2020-03-07 07:21:16           https://www.travel-advisory.info/burundi
# 137  2020-03-07 07:21:16              https://www.travel-advisory.info/mali
# 99   2020-03-07 07:21:16              https://www.travel-advisory.info/iraq

# %%
#15 - I will sort my data frame to find the top 10 safest countries.

all_safe = main_df.sort_values('Score', ascending=True).head(10)
all_safe
# Out:
#                           Name ISO      Continent  Score          Status  \
# 161                       Niue  NU        Oceania    0.0  Extremely Safe
# 34               Cocos Islands  CC  South America    0.0  Extremely Safe
# 172                   Pitcairn  PN        Oceania    0.0  Extremely Safe
# 171  Saint Pierre and Miquelon  PM  North America    0.0  Extremely Safe
# 40                Cook Islands  CK        Oceania    0.0  Extremely Safe
# 155             Norfolk Island  NF        Oceania    0.0  Extremely Safe
# 48            Christmas Island  CX        Oceania    0.0  Extremely Safe
# 141   Northern Mariana Islands  MP        Oceania    0.0  Extremely Safe
# 133               Saint Martin  MF  North America    0.0  Extremely Safe
# 60              Western Sahara  EH         Africa    0.0  Extremely Safe
#
#              Last Update                                             Source
# 161  2020-03-07 07:21:16              https://www.travel-advisory.info/niue
# 34   2020-03-07 07:21:16     https://www.travel-advisory.info/cocos-islands
# 172  2020-03-07 07:21:16          https://www.travel-advisory.info/pitcairn
# 171  2020-03-07 07:21:16  https://www.travel-advisory.info/saint-pierre-...
# 40   2020-03-07 07:21:16      https://www.travel-advisory.info/cook-islands
# 155  2020-03-07 07:21:16    https://www.travel-advisory.info/norfolk-island
# 48   2020-03-07 07:21:16  https://www.travel-advisory.info/christmas-island
# 141  2020-03-07 07:21:16  https://www.travel-advisory.info/northern-mari...
# 133  2020-03-07 07:21:16      https://www.travel-advisory.info/saint-martin
# 60   2020-03-07 07:21:16    https://www.travel-advisory.info/western-sahara

# %%
#16 - I will look at the safest countries in America.

america_safe = main_df[(main_df['Continent']=='North America') | (main_df['Continent']=='South America')].sort_values('Score', ascending=True).head(10)
america_safe
# Out:
#                           Name ISO      Continent  Score          Status  \
# 66            Falkland Islands  FK  South America    0.0  Extremely Safe
# 78                   Greenland  GL  North America    0.0  Extremely Safe
# 171  Saint Pierre and Miquelon  PM  North America    0.0  Extremely Safe
# 34               Cocos Islands  CC  South America    0.0  Extremely Safe
# 23            Saint Barthélemy  BL  North America    0.0  Extremely Safe
# 133               Saint Martin  MF  North America    0.0  Extremely Safe
# 81                  Guadeloupe  GP  North America    1.0  Extremely Safe
# 226     British Virgin Islands  VG  North America    1.0  Extremely Safe
# 112      Saint Kitts and Nevis  KN  North America    1.0  Extremely Safe
# 3          Antigua and Barbuda  AG  North America    1.0  Extremely Safe
#
#              Last Update                                             Source
# 66   2020-03-07 07:21:16  https://www.travel-advisory.info/falkland-islands
# 78   2020-03-07 07:21:16         https://www.travel-advisory.info/greenland
# 171  2020-03-07 07:21:16  https://www.travel-advisory.info/saint-pierre-...
# 34   2020-03-07 07:21:16     https://www.travel-advisory.info/cocos-islands
# 23   2020-03-07 07:21:16  https://www.travel-advisory.info/saint-barthelemy
# 133  2020-03-07 07:21:16      https://www.travel-advisory.info/saint-martin
# 81   2020-03-07 07:21:16        https://www.travel-advisory.info/guadeloupe
# 226  2020-03-07 07:21:16  https://www.travel-advisory.info/british-virgi...
# 112  2020-03-07 07:21:16  https://www.travel-advisory.info/saint-kitts-a...
# 3    2020-03-07 07:21:16  https://www.travel-advisory.info/antigua-and-b...

# %%
#17 - I will look at the most dangerous countries in America.

america_dangerous = main_df[(main_df['Continent']=='North America') | (main_df['Continent']=='South America')].sort_values('Score', ascending=False).head(10)
america_dangerous
# Out:
#                     Name ISO      Continent  Score               Status  \
# 225            Venezuela  VE  South America    4.4  Extremely Dangerous
# 92                 Haiti  HT  North America    4.2  Extremely Dangerous
# 157            Nicaragua  NI  North America    3.4            Dangerous
# 74         French Guiana  GF  South America    3.0              Caution
# 90              Honduras  HN  North America    2.8              Caution
# 26               Bolivia  BO  South America    2.7              Caution
# 104              Jamaica  JM  North America    2.6              Caution
# 85             Guatemala  GT  North America    2.6              Caution
# 214  Trinidad and Tobago  TT  North America    2.6              Caution
# 44              Colombia  CO  South America    2.5              Caution
#
#              Last Update                                             Source
# 225  2020-03-07 07:21:16         https://www.travel-advisory.info/venezuela
# 92   2020-03-07 07:21:16             https://www.travel-advisory.info/haiti
# 157  2020-03-07 07:21:16         https://www.travel-advisory.info/nicaragua
# 74   2020-03-07 07:21:16     https://www.travel-advisory.info/french-guiana
# 90   2020-03-07 07:21:16          https://www.travel-advisory.info/honduras
# 26   2020-03-07 07:21:16           https://www.travel-advisory.info/bolivia
# 104  2020-03-07 07:21:16           https://www.travel-advisory.info/jamaica
# 85   2020-03-07 07:21:16         https://www.travel-advisory.info/guatemala
# 214  2020-03-07 07:21:16  https://www.travel-advisory.info/trinidad-and-...
# 44   2020-03-07 07:21:16          https://www.travel-advisory.info/colombia

# %%
#18 - I will look at safest and most dangerous countries in Europe.

europe_safe = main_df[(main_df['Continent']=='Europe')].sort_values('Score', ascending=True).head(10)
europe_dangerous = main_df[(main_df['Continent']=='Europe')].sort_values('Score', ascending=False).head(10)

# %%
#19 - I will look at safest and most dangerous countries in Asia.

asia_safe = main_df[(main_df['Continent']=='Asia')].sort_values('Score', ascending=True).head(10)
asia_dangerous = main_df[(main_df['Continent']=='Asia')].sort_values('Score', ascending=False).head(10)

# %%
#20 - I will look at safest and most dangerous countries in Africa.

africa_safe = main_df[(main_df['Continent']=='Africa')].sort_values('Score', ascending=True).head(10)
africa_dangerous = main_df[(main_df['Continent']=='Africa')].sort_values('Score', ascending=False).head(10)

# %%
#21 - I will look at safest and most dangerous countries in Oceania.

oceania_safe = main_df[(main_df['Continent']=='Oceania')].sort_values('Score', ascending=True).head(10)
oceania_dangerous = main_df[(main_df['Continent']=='Oceania')].sort_values('Score', ascending=False).head(10)

# %%
# - I will look at the average score for each of the continents.

continent_safety = main_df.groupby('Continent', as_index=False).agg({'Score':'mean'})
continent_safety.columns = ['Continent', 'Score']

continent_safety.sort_values('Score', ascending=False)
# Out:
#        Continent     Score
# 0         Africa  2.660345
# 2           Asia  2.612245
# 6  South America  2.146667
# 4  North America  1.615789
# 3         Europe  1.386538
# 5        Oceania  0.832000
# 1     Antarctica  0.000000

# %% [markdown]
# ### IV. Reporting

# %%
#19 - I will export my 'clean' data frame as a .csv file

main_df.to_csv('/Users/alejandroarrya/Desktop/Ironhack/DAFTMX/web-project/Output/api_clean.csv')

# %% [markdown]
# ### V. Pipeline

# %%
import requests
import json
import pandas as pd
ta_url = 'https://www.travel-advisory.info/api'

class Continent:
    
    def __init__(self, name):
        self.name = name

    def safe_countries(self, safe=True):
        self.safe = safe
        self.data = requests.get(ta_url)
        self.data_json = self.data.json()
        
        self.df = pd.DataFrame(self.data_json['data'])
        self.df.columns = [x for x in range(len(self.df.columns))]
        self.df = self.df.transpose()
        
        advisory_columns = [dictionary.keys() for dictionary in self.df['advisory']][0]
        advisory_indeces = [dictionary.values() for dictionary in self.df['advisory']]
        advisory_df = pd.DataFrame(advisory_indeces, columns=advisory_columns)
        
        self.main_df = pd.concat([advisory_df, self.df], axis=1)
        columns_to_drop = ['advisory', 'message','sources_active']
        self.main_df = self.main_df.drop(columns_to_drop, axis=1)
        
        self.main_df['continent'] = self.main_df.continent.replace('EU', 'Europe').replace('AF', 'Africa').replace('NA', 'North America').replace('SA', 'South America').replace('AS', 'Asia').replace('AN', 'Antarctica').replace('OC', 'Oceania')

        safety_labels = ['Exercise Normal Precautions','Exercised Increased Caution','Reconsider Travel','Do Not Travel']
        bins = pd.cut(self.main_df['score'],[0, 2.5, 3.5, 4.5, 5], labels=safety_labels, include_lowest=True)
        self.main_df['status'] = bins
        
        column_order = [
            'name',
            'iso_alpha2',
            'continent',
            'score',
            'status',
            'updated',
            'source'
        ]
        self.main_df = self.main_df[column_order]
        
        self.main_df.columns = [
            'Name',
            'ISO',
            'Continent',
            'Score',
            'Status',
            'Last Update',
            'Source'
        ]        
        
        if self.name == 'America' and self.safe == True:
            print(self.main_df[(self.main_df['Continent']=='North America') | (self.main_df['Continent']=='South America')].sort_values('Score', ascending=True).head(10))

        elif self.name == 'America' and self.safe == False:
            print(self.main_df[(self.main_df['Continent']=='North America') | (self.main_df['Continent']=='South America')].sort_values('Score', ascending=False).head(10))
        
        elif self.name == 'Europe' and self.safe == True:
            print(self.main_df[(self.main_df['Continent']=='Europe')].sort_values('Score', ascending=True).head(10))
            
        elif self.name == 'Europe' and self.safe == False:
            print(self.main_df[(self.main_df['Continent']=='Europe')].sort_values('Score', ascending=False).head(10))
            
        elif self.name == 'Asia' and self.safe == True:
            print(self.main_df[(self.main_df['Continent']=='Asia')].sort_values('Score', ascending=True).head(10))
            
        elif self.name == 'Asia' and self.safe == False:
            print(self.main_df[(self.main_df['Continent']=='Asia')].sort_values('Score', ascending=False).head(10))
            
        elif self.name == 'Africa' and self.safe == True:
            print(self.main_df[(self.main_df['Continent']=='Africa')].sort_values('Score', ascending=True).head(10))
            
        elif self.name == 'Africa' and self.safe == False:
            print(self.main_df[(self.main_df['Continent']=='Africa')].sort_values('Score', ascending=False).head(10))
            
        elif self.name == 'Oceania' and self.safe == True:
            print(self.main_df[(self.main_df['Continent']=='Oceania')].sort_values('Score', ascending=True).head(10))
            
        elif self.name == 'Oceania' and self.safe == False:
            print(self.main_df[(self.main_df['Continent']=='Oceania')].sort_values('Score', ascending=False).head(10))
            
        elif self.name == 'All' and self.safe == True:
            print(self.main_df.sort_values('Score', ascending=True).head(10))
            
        elif self.name == 'All' and self.safe == False:
            print(self.main_df.sort_values('Score', ascending=False).head(10))
            
print('\nWelcome to the Travel Advisory Board, the place to find out where to go and where NOT to go!')
print('This program will list the top 10 safest or most dangerous countries in each continent.\n')

continent = input('To start, please type the name of the continent you wish to visit: ')
safe = input("Now, type 'D' for the most dangerous countries in that continent or 'S' for the safest: " )

if safe == 'D':
    safe = False
elif safe == 'S':
    safe = True

c = Continent(continent)
c.safe_countries(safe)
# Out:
# Welcome to the Travel Advisory Board, the place to find out where to go and where NOT to go!
# This program will list the top 10 safest or most dangerous countries in each continent.
#
# To start, please type the name of the continent you wish to visit: America
# Now, type 'D' for the most dangerous countries in that continent or 'S' for the safest: S
#                           Name ISO      Continent  Score  \
# 66            Falkland Islands  FK  South America    0.0
# 78                   Greenland  GL  North America    0.0
# 171  Saint Pierre and Miquelon  PM  North America    0.0
# 34               Cocos Islands  CC  South America    0.0
# 23            Saint Barthélemy  BL  North America    0.0
# 133               Saint Martin  MF  North America    0.0
# 81                  Guadeloupe  GP  North America    1.0
# 226     British Virgin Islands  VG  North America    1.0
# 112      Saint Kitts and Nevis  KN  North America    1.0
# 3          Antigua and Barbuda  AG  North America    1.0
#
#                           Status          Last Update  \
# 66   Exercise Normal Precautions  2020-03-07 07:21:16
# 78   Exercise Normal Precautions  2020-03-07 07:21:16
# 171  Exercise Normal Precautions  2020-03-07 07:21:16
# 34   Exercise Normal Precautions  2020-03-07 07:21:16
# 23   Exercise Normal Precautions  2020-03-07 07:21:16
# 133  Exercise Normal Precautions  2020-03-07 07:21:16
# 81   Exercise Normal Precautions  2020-03-07 07:21:16
# 226  Exercise Normal Precautions  2020-03-07 07:21:16
# 112  Exercise Normal Precautions  2020-03-07 07:21:16
# 3    Exercise Normal Precautions  2020-03-07 07:21:16
#
#                                                 Source
# 66   https://www.travel-advisory.info/falkland-islands
# 78          https://www.travel-advisory.info/greenland
# 171  https://www.travel-advisory.info/saint-pierre-...
# 34      https://www.travel-advisory.info/cocos-islands
# 23   https://www.travel-advisory.info/saint-barthelemy
# 133      https://www.travel-advisory.info/saint-martin
# 81         https://www.travel-advisory.info/guadeloupe
# 226  https://www.travel-advisory.info/british-virgi...
# 112  https://www.travel-advisory.info/saint-kitts-a...
# 3    https://www.travel-advisory.info/antigua-and-b...
